# %% [markdown]
# # **Start**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     270             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     271         )
# --> 272       raise ValueError('mount failed' + extra_reason)
#     273     elif case == 4:
#     274       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
# Uninstall existing scikit-learn to avoid conflicts
# !pip uninstall -y scikit-learn
# Install specific versions of libraries to avoid conflicts
# !pip install scikit-learn==1.5.2
# !pip install bayesian-optimization
# !pip install optuna
# !pip install gpboost
# !pip install shap
# !pip install ngboost
# !pip install dask[dataframe]
# !pip install torch seaborn
# !pip install lightgbm
# !pip install xgboost
# !pip install lime
# !pip install interpret
# !pip install optunahub
# !pip install cmaes
# !pip install plotly kaleido
# !pip install openpyxl
# !pip install -U kaleido
# !pip install properscoring
# !pip install XlsxWriter
# !pip install cython
# !pip install pgbm
# !pip install torch
# !pip install cp
# !pip install mapie
# !pip install torch skorch puncc
# Reinstall scikit-learn to the version required by ngboost
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.6.1
# Reinstall numpy first
# !pip install numpy==1.26.4  # Use the version compatible with catboost
# Reinstall catboost
# !pip install catboost

# %%
# Restart the runtime to apply changes
import os
os._exit(00)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ngboost
from scipy.stats import randint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from gpboost import GPBoostRegressor
from ngboost import NGBRegressor
import optuna
import optunahub
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from interpret import show
from interpret.blackbox import LimeTabular, ShapKernel
from optuna.samplers import RandomSampler
import random
import time
from ngboost.distns import Normal
from ngboost.scores import LogScore
from scipy.stats import norm
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from interpret.glassbox import ExplainableBoostingRegressor
from interpret import show
import plotly.express as px
from io import BytesIO
from openpyxl import Workbook, load_workbook
import os
from openpyxl.drawing.image import Image as openpyxlImage
import warnings
import xlsxwriter
from openpyxl.drawing.image import Image
from pgbm.sklearn import HistGradientBoostingRegressor
import torch
from pgbm.torch import PGBM
import plotly.graph_objects as go
warnings.filterwarnings('ignore')
import pickle
import json
# Out:
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu124/split_decision...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu124/split_decision/build.ninja...
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Building extension module split_decision...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module split_decision...
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# No modifications detected for re-loaded extension module split_decision, skipping build step...
# Loading extension module split_decision...

# %%
train_data_path = "./drive/MyDrive/NOISE/train.csv"
test_data_path = "./drive/MyDrive/NOISE/test.csv"
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
print("Training data loaded successfully.")
print("Test data loaded successfully.")
# Out:
# Training data loaded successfully.
# Test data loaded successfully.

# %%
print("\nShape of training data:", train_data.shape)
print("First 5 rows of training data:\n", train_data.head(5))
print("\nShape of test data:", test_data.shape)
print("First 5 rows of test data:\n", test_data.head(5))
# Out:
# Shape of training data: (168, 6)
# First 5 rows of training data:
#        A    B    C    D   O    Leq
# 0   894  354  228   30  42  70.06
# 1  1068  312  234   24  24  69.14
# 2  1506  894  198  222  18  73.02
# 3  1188  498  252  354  18  75.71
# 4  1068  438  210  366  30  70.78
#
# Shape of test data: (60, 6)
# First 5 rows of test data:
#        A    B    C    D   O    Leq
# 0  1032  282   90  108   6  70.07
# 1  1188  498  252  408  18  72.90
# 2   570   90   60   84  24  68.66
# 3   450  156  150   72   0  50.24
# 4   240   66   18   24   0  40.17

# %%
X_train = train_data.iloc[:, :-1]
y_train = train_data.iloc[:, -1]
X_test = test_data.iloc[:, :-1]
y_test = test_data.iloc[:, -1]
x_test= X_test
print("\nShape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (168, 5)
# Shape of y_train: (168,)
# Shape of X_test: (60, 5)
# Shape of y_test: (60,)

# %%
# Apply z-score normalization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Print the first five rows of the normalized data
print("\nFirst five rows of normalized X_train:")
print(X_train[:5])

print("\nFirst five rows of normalized X_test:")
print(X_test[:5])
# Out:
# First five rows of normalized X_train:
# [[-0.34508703 -0.52871218  0.0597039  -1.05667951  1.31930842]
#  [-0.08377773 -0.63289541  0.09903824 -1.09452265  0.25541811]
#  [ 0.57400083  0.8107865  -0.13696778  0.15430089 -0.09921199]
#  [ 0.09643557 -0.17151253  0.21704125  0.98684991 -0.09921199]
#  [-0.08377773 -0.32034572 -0.05829911  1.06253618  0.61004822]]
#
# First five rows of normalized X_test:
# [[-0.13784172 -0.707312   -0.84498584 -0.56471872 -0.8084722 ]
#  [ 0.09643557 -0.17151253  0.21704125  1.32743815 -0.09921199]
#  [-0.83166295 -1.1835782  -1.04165752 -0.71609127  0.25541811]
#  [-1.01187626 -1.01986169 -0.45164247 -0.79177755 -1.16310231]
#  [-1.32724954 -1.24311147 -1.31699788 -1.09452265 -1.16310231]]

# %%
# Define the model classes
model_classes = {
    'Random Forest': RandomForestRegressor,
    'Gradient Boosting': GradientBoostingRegressor,
    'XGBoost': XGBRegressor,
    'LightGBM': LGBMRegressor,
    'GPBoost': GPBoostRegressor,
    'CatBoost': CatBoostRegressor,
    'NGBoost': NGBRegressor
}

feature_names = ['A', 'B', 'C', 'D', 'O']

# %%
def plot_best_scores(best_scores_ran, excel_file_path):
    # Extract the best pruner for each model based on RMSE and correlation coefficient
    best_rmse_scores = {}
    best_corr_coef_scores = {}

    for (model_name, pruner_name), scores in best_scores_ran.items():
        # Initialize if not already present
        if model_name not in best_rmse_scores:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if model_name not in best_corr_coef_scores:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

        # Update if better scores are found
        if scores['test_rmse'] < best_rmse_scores[model_name][0]:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if scores['test_corr_coef'] > best_corr_coef_scores[model_name][0]:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

    # Prepare data for plotting
    model_names_rmse = [f"{model} ({pruner})" for model, (rmse, pruner) in best_rmse_scores.items()]
    rmse_values = [rmse for rmse, _ in best_rmse_scores.values()]

    model_names_corr = [f"{model} ({pruner})" for model, (corr, pruner) in best_corr_coef_scores.items()]
    corr_values = [corr for corr, _ in best_corr_coef_scores.values()]

    # Plot RMSE
    plt.figure(figsize=(12, 6))
    bars_rmse = plt.bar(model_names_rmse, rmse_values, color='skyblue')

    # Highlight the best model
    best_rmse_index = np.argmin(rmse_values)
    bars_rmse[best_rmse_index].set_color('orange')

    # Annotate the bars with the RMSE scores
    for i, bar in enumerate(bars_rmse):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{rmse_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the RMSE bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Test RMSE')
    plt.title('Best Test RMSE for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    rmse_image_path = 'rmse_plot.png'
    plt.savefig(rmse_image_path)
    plt.close()

    # Plot Correlation Coefficient
    plt.figure(figsize=(12, 6))
    bars_corr = plt.bar(model_names_corr, corr_values, color='lightgreen')

    # Highlight the best model
    best_corr_index = np.argmax(corr_values)
    bars_corr[best_corr_index].set_color('orange')

    # Annotate the bars with the correlation coefficient scores
    for i, bar in enumerate(bars_corr):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{corr_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the correlation coefficient bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Correlation Coefficient')
    plt.title('Best Correlation Coefficient for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    corr_image_path = 'corr_plot.png'
    plt.savefig(corr_image_path)
    plt.close()

    # Load the existing Excel file
    workbook = load_workbook(excel_file_path)

    # Create a new sheet for the plots
    sheet_name = 'Best Models Plots'
    if sheet_name in workbook.sheetnames:
        sheet = workbook[sheet_name]
    else:
        sheet = workbook.create_sheet(title=sheet_name)

    # Insert images into the new Excel sheet
    img_rmse = Image(rmse_image_path)
    img_corr = Image(corr_image_path)

    # Insert images
    sheet.add_image(img_rmse, 'A1')
    sheet.add_image(img_corr, 'A20')  # Adjust the position as needed

    # Save the workbook
    workbook.save(excel_file_path)

    # Clean up the image files
    os.remove(rmse_image_path)
    os.remove(corr_image_path)

# Example usage
# plot_best_scores(best_scores_ran, 'path_to_your_excel_file.xlsx')

# %%
def generate_interpretml_explanations_summary_pruners(
    results_dict, X_train, y_train, X_test, feature_names, instance_indices=None, excel_file_path=None
):
    if instance_indices is None:
        instance_indices = range(len(X_test))
    elif isinstance(instance_indices, int):
        instance_indices = [instance_indices]

    valid_indices = [idx for idx in instance_indices if 0 <= idx < len(X_test)]
    if not valid_indices:
        print("No valid instance indices provided.")
        return

    if isinstance(X_test, pd.DataFrame):
        instances_to_explain = X_test.iloc[valid_indices]
    else:
        instances_to_explain = X_test[valid_indices]

    best_model_pruners = {}
    for model_key, model_info in results_dict.items():
        if isinstance(model_key, tuple):
            model_name, pruner_name = model_key
        else:
            model_name = model_key
            pruner_name = None

        best_score = model_info.get('best_score')
        if best_score is None:
            print(f"No 'best_score' found for {model_key}. Skipping this combination.")
            continue

        if model_name not in best_model_pruners:
            best_model_pruners[model_name] = {
                'pruner_name': pruner_name,
                'model_info': model_info,
                'best_score': best_score
            }
        else:
            current_best_score = best_model_pruners[model_name]['best_score']
            if best_score < current_best_score:
                best_model_pruners[model_name] = {
                    'pruner_name': pruner_name,
                    'model_info': model_info,
                    'best_score': best_score
                }

    for model_name, info in best_model_pruners.items():
        pruner_name = info['pruner_name']
        model_info = info['model_info']
        best_params = model_info['best_params']
        model_class = model_classes.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        if model_name == 'CatBoost':
            best_params['verbose'] = 0

        model = model_class(**best_params)
        model.fit(X_train, y_train)

        def predict_fn(data):
            return model.predict(data)

        if isinstance(X_train, pd.DataFrame):
            data_for_explainer = X_train.values
        else:
            data_for_explainer = X_train

        if isinstance(instances_to_explain, pd.DataFrame):
            data_for_explanation = instances_to_explain.values
        else:
            data_for_explanation = instances_to_explain

        # Generate LIME explanations
        lime_explainer = LimeTabular(
            predict_fn,
            data=data_for_explainer,
            feature_names=feature_names,
            random_state=1,
            mode='regression'
        )
        lime_explanation = lime_explainer.explain_local(data_for_explanation)

        feature_importances_lime = {}
        num_instances = len(valid_indices)

        for idx in range(num_instances):
            explanation = lime_explanation.data(idx)
            for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                feature_importances_lime[feature_name] = feature_importances_lime.get(feature_name, 0) + abs(feature_score)

        feature_importances_lime = {k: v / num_instances for k, v in feature_importances_lime.items()}
        feature_importances_lime = {k: round(v, 3) for k, v in feature_importances_lime.items()}

        # Generate SHAP explanations using ShapKernel
        try:
            shap_explainer = ShapKernel(predict_fn, data_for_explainer, feature_names=feature_names)
            shap_explanation = shap_explainer.explain_local(data_for_explanation)

            feature_importances_shap = {}
            for idx in range(num_instances):
                explanation = shap_explanation.data(idx)
                for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                    feature_importances_shap[feature_name] = feature_importances_shap.get(feature_name, 0) + abs(feature_score)

            feature_importances_shap = {k: v / num_instances for k, v in feature_importances_shap.items()}
            feature_importances_shap = {k: round(v, 3) for k, v in feature_importances_shap.items()}
        except Exception as e:
            print(f"Could not compute SHAP values for model {model_name}: {e}")
            continue

        # Plot LIME and SHAP feature importances side by side
        fig, axes = plt.subplots(1, 2, figsize=(34, 36))

        # Plot LIME feature importances
        lime_importances_df = pd.DataFrame.from_dict(
            feature_importances_lime, orient='index', columns=['importance']
        )
        lime_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        lime_importances_df.plot(kind='bar', legend=False, color='skyblue', ax=axes[0])
        axes[0].set_title(f"LIME Feature Importances for {model_name}")
        axes[0].set_ylabel("Average Absolute Importance Score")
        axes[0].set_xlabel("Features")
        axes[0].tick_params(axis='x', rotation=45)

        for p in axes[0].patches:
            height = p.get_height()
            axes[0].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        # Plot SHAP feature importances
        shap_importances_df = pd.DataFrame.from_dict(
            feature_importances_shap, orient='index', columns=['importance']
        )
        shap_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        shap_importances_df.plot(kind='bar', legend=False, color='orange', ax=axes[1])
        axes[1].set_title(f"SHAP Feature Importances for {model_name}")
        axes[1].set_ylabel("Average Absolute SHAP Value")
        axes[1].set_xlabel("Features")
        axes[1].tick_params(axis='x', rotation=45)

        for p in axes[1].patches:
            height = p.get_height()
            axes[1].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        plt.tight_layout()

        # Save plots as images
        image_path = f'feature_importances_{model_name}.png'
        fig.savefig(image_path)
        plt.close(fig)

        # Optionally insert images and scores into an Excel file
        if excel_file_path:
            workbook = load_workbook(excel_file_path)
            sheet_name = f'{model_name} Explanations'
            if sheet_name in workbook.sheetnames:
                sheet = workbook[sheet_name]
            else:
                sheet = workbook.create_sheet(title=sheet_name)

            # Insert images into the new Excel sheet
            img = Image(image_path)
            sheet.add_image(img, 'A1')

            # Create a new sheet for feature importance scores
            scores_sheet_name = f'{model_name} Scores'
            if scores_sheet_name in workbook.sheetnames:
                scores_sheet = workbook[scores_sheet_name]
            else:
                scores_sheet = workbook.create_sheet(title=scores_sheet_name)

            # Write LIME scores
            scores_sheet.append(['Feature', 'LIME Importance'])
            for feature, importance in feature_importances_lime.items():
                scores_sheet.append([feature, importance])

            # Write SHAP scores
            scores_sheet.append(['Feature', 'SHAP Importance'])
            for feature, importance in feature_importances_shap.items():
                scores_sheet.append([feature, importance])

            # Save the workbook
            workbook.save(excel_file_path)

            # Clean up the image file
            os.remove(image_path)

# %% [markdown]
# # **Autosampler by Optuna**

# %%
# Suppress Optuna's verbose output
optuna.logging.set_verbosity(optuna.logging.WARNING)

# Define objective and metric functions for PGBM
def mseloss_objective(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    gradient = yhat - y
    hessian = torch.ones_like(yhat)
    return gradient, hessian

def rmseloss_metric(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    loss = torch.sqrt(torch.mean((yhat - y) ** 2))
    return loss

def hyperparameter_tuning_all(X_train, y_train, X_test, y_test, excel_path):
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    models = {
        'Random Forest': (RandomForestRegressor, {
            'n_estimators': [100, 200, 300, 500, 700],
            'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
            'max_depth': [None, 10, 20, 30, 40],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.1, 0.2],
            'max_features': [1.0, 'sqrt', 'log2', 0.3, 0.5],
            'max_leaf_nodes': [None, 50, 100, 200],
            'min_impurity_decrease': [0.0, 0.01, 0.1, 0.2],
            'n_jobs': [-1],
            'random_state': [42],
            'verbose': [0],
            'warm_start': [False],
            'ccp_alpha': [0.0, 0.001, 0.01, 0.05, 0.1]
        }),
        'Gradient Boosting': (GradientBoostingRegressor, {
            'loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
            'learning_rate': [0.01, 0.05, 0.1, 0.2],
            'n_estimators': [100, 200, 300, 500, 700],
            'subsample': [1.0, 0.9, 0.7, 0.5],
            'criterion': ['friedman_mse', 'squared_error'],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.05, 0.1],
            'max_depth': [3, 5, 7, 10],
            'min_impurity_decrease': [0.0, 0.01, 0.1],
            'init': [None],
            'random_state': [42],
            'max_features': [None, 'sqrt', 'log2', 0.5],
            'alpha': [0.9, 0.5, 0.1],
            'verbose': [0],
            'max_leaf_nodes': [None, 10, 30, 50],
            'warm_start': [False],
            'validation_fraction': [0.1],
            'n_iter_no_change': [None, 10, 20],
            'tol': [1e-4, 1e-3],
            'ccp_alpha': [0.0, 0.001, 0.01]
        }),
        'XGBoost': (XGBRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'min_child_weight': [1, 3, 5],
            'gamma': [0, 0.1, 0.5, 1],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            'colsample_bylevel': [0.5, 0.7, 0.9],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0.1, 1, 5, 10],
            'objective': ['reg:squarederror'],
            'random_state': [42],
            'n_jobs': [-1]
        }),
        'LightGBM': (LGBMRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'num_leaves': [15, 31, 63],
            'max_depth': [3, 5, 7, -1],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0, 0.1, 1, 10],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'bagging_freq': [0, 1, 5],
            'objective': ['regression'],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'GPBoost': (GPBoostRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7, -1],
            'num_leaves': [15, 31, 63],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.1, 0.5, 1.0],
            'reg_lambda': [0, 0.1, 0.5, 1.0],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'CatBoost': (CatBoostRegressor, {
            'iterations': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'depth': [4, 6, 8, 10],
            'l2_leaf_reg': [1, 3, 5, 7, 9],
            'border_count': [32, 64, 128],
            'min_data_in_leaf': [1, 5, 10, 20],
            'rsm': [0.6, 0.8, 1.0],
            'bagging_temperature': [0, 1, 10],
            'random_seed': [42],
            'verbose': [0]
        }),
        'NGBoost': (NGBRegressor, {
            'n_estimators': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'natural_gradient': [True, False],
            'minibatch_frac': [0.5, 0.7, 0.9, 1.0],
            'col_sample': [0.5, 0.7, 0.9, 1.0],
            'Dist': [Normal],
            'Score': [LogScore],
            'random_state': [42],
            'verbose': [0]
        }),
        'HistGradientBoosting': (HistGradientBoostingRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_iter': [100, 200, 300, 400, 500],
            'max_depth': [3, 5, 7, None],
            'min_samples_leaf': [5, 10, 20],
            'max_leaf_nodes': [15, 31, 63, None],
            'l2_regularization': [0.0, 0.1, 0.5, 1.0],
            'max_bins': [64, 128, 255],
            'early_stopping': [True, False],
            'validation_fraction': [0.1, 0.2],
            'n_iter_no_change': [5, 10, 15],
            'loss': ['squared_error'],
            'random_state': [42],
            'verbose': [0]
        }),
        'PGBM': (PGBM, {}) # PGBM is handled separately
    }


    pruners = [
        optuna.pruners.MedianPruner(),
        optuna.pruners.NopPruner(),
        optuna.pruners.PatientPruner(optuna.pruners.MedianPruner(), patience=3),
        optuna.pruners.PercentilePruner(25.0),
        optuna.pruners.SuccessiveHalvingPruner(),
        optuna.pruners.HyperbandPruner(),
        optuna.pruners.ThresholdPruner(lower=0.1),
        optuna.pruners.WilcoxonPruner()
    ]

    best_scores = {}
    predictions_df = pd.DataFrame({'Actual': y_test})

    for model_name, (model_class, param_space) in models.items():
        for pruner in pruners:
            pruner_name = pruner.__class__.__name__
            print(f"Running Optuna for {model_name} with {pruner_name}...")
            try:
                sampler = optunahub.load_module("samplers/auto_sampler").AutoSampler()
                study = optuna.create_study(direction='minimize', sampler=sampler, pruner=pruner)

                if model_name == 'PGBM':
                    def pgbm_objective(trial):
                        params = {
                            'n_estimators': trial.suggest_categorical('n_estimators', [100, 200, 300, 500]),
                            'learning_rate': trial.suggest_categorical('learning_rate', [0.01, 0.05, 0.1, 0.15]),
                            'max_leaves': trial.suggest_int('max_leaves', 15, 63),
                            'min_split_gain': trial.suggest_categorical('min_split_gain', [0.0, 0.1, 0.5, 1.0]),
                            'reg_lambda': trial.suggest_categorical('reg_lambda', [0.1, 1.0, 5.0, 10.0]),
                            'feature_fraction': trial.suggest_categorical('feature_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'bagging_fraction': trial.suggest_categorical('bagging_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'tree_correlation': trial.suggest_categorical('tree_correlation', [0.0, 0.1, 0.2, 0.3]),
                            'min_data_in_leaf': trial.suggest_categorical('min_data_in_leaf', [3, 5, 10, 20]),
                            'max_bin': trial.suggest_categorical('max_bin', [64, 128, 256]),
                            'distribution': trial.suggest_categorical('distribution', ['normal', 'studentt', 'laplace']),
                            'objective': 'mse',
                            'metric': 'rmse',
                            'random_state': 42,
                            'verbose': 0
                        }

                        model = PGBM()
                        model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=params)
                        y_pred = model.predict(X_test)
                        mse = mean_squared_error(y_test, y_pred)
                        return mse

                    study.optimize(pgbm_objective, n_trials=50)
                else:
                    def objective(trial, model_name, model_class, param_space):
                        params = {}
                        for key, values in param_space.items():
                            if isinstance(values, list):
                                params[key] = trial.suggest_categorical(key, values)
                            elif isinstance(values, tuple):
                                if len(values) == 2:
                                    params[key] = trial.suggest_float(key, values[0], values[1])
                                elif len(values) == 3 and isinstance(values[2], bool) and values[2]:
                                    params[key] = trial.suggest_int(key, values[0], values[1])
                                else:
                                    raise ValueError(f"Invalid parameter range for {key}")

                        model = model_class(**params)
                        model.fit(X_train, y_train)
                        y_pred = model.predict(X_test)
                        mse = mean_squared_error(y_test, y_pred)
                        return mse

                    study.optimize(lambda trial: objective(trial, model_name, model_class, param_space), n_trials=50)

                best_params = study.best_params
                best_model = model_class(**best_params) if model_name != 'PGBM' else PGBM()
                if model_name == 'PGBM':
                    best_model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params)
                else:
                    best_model.fit(X_train, y_train)
                y_pred = best_model.predict(X_test)

                mse = mean_squared_error(y_test, y_pred)
                rmse = np.sqrt(mse)
                corr_coef = np.corrcoef(y_test, y_pred)[0, 1]

                # Save predictions to DataFrame
                predictions_df[f'{model_name}_{pruner_name}_Predicted'] = y_pred

                best_scores[(model_name, pruner_name)] = {
                    'best_score': mse,
                    'best_params': best_params,
                    'test_mse': mse,
                    'test_rmse': rmse,
                    'test_corr_coef': corr_coef,
                    'pruner': pruner_name
                }
                print(f"Best MSE for {model_name} with {pruner_name}: {mse} with params: {best_params}")
                print(f"Best RMSE for {model_name} with {pruner_name}: {rmse}")
                print(f"Correlation Coefficient for {model_name} with {pruner_name}: {corr_coef}")
            except Exception as e:
                print(f"Failed to run Optuna for {model_name} with {pruner_name}. Error: {e}")

    # Write predictions to Excel
    with pd.ExcelWriter(excel_path, engine='openpyxl', mode='a') as writer:
        predictions_df.to_excel(writer, sheet_name='Predictions', index=False)

    if best_scores:
        best_model_name, best_pruner_name = min(best_scores, key=lambda k: best_scores[k]['test_mse'])
        best_model_info = best_scores[(best_model_name, best_pruner_name)]
        print(f"\nBest model on test data: {best_model_name} with {best_pruner_name}")
        print(f"Test MSE: {best_model_info['test_mse']}")
        print(f"Test RMSE: {best_model_info['test_rmse']}")
        print(f"Correlation Coefficient: {best_model_info['test_corr_coef']}")
        print(f"Best Parameters: {best_model_info['best_params']}")
        print(f"Pruner Used: {best_model_info['pruner']}")
    else:
        print("No valid model configurations found.")

    return best_scores

# Example usage
best_scores_autosampler = hyperparameter_tuning_all(X_train, y_train, X_test, y_test, "./drive/MyDrive/NOISE/noise_ml/HyperParameter_Tuning/test.xlsx")
# Out:
# Running Optuna for Random Forest with MedianPruner...
# Best MSE for Random Forest with MedianPruner: 13.038158161806736 with params: {'n_estimators': 500, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}
# Best RMSE for Random Forest with MedianPruner: 3.610838983090597
# Correlation Coefficient for Random Forest with MedianPruner: 0.9708197958491004
# Running Optuna for Random Forest with NopPruner...
# Best MSE for Random Forest with NopPruner: 13.033087634585193 with params: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}
# Best RMSE for Random Forest with NopPruner: 3.6101367889022145
# Correlation Coefficient for Random Forest with NopPruner: 0.9707049346475258
# Running Optuna for Random Forest with PatientPruner...
# Best MSE for Random Forest with PatientPruner: 14.454469361060458 with params: {'n_estimators': 500, 'criterion': 'squared_error', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}
# Best RMSE for Random Forest with PatientPruner: 3.801903386602618
# Correlation Coefficient for Random Forest with PatientPruner: 0.968585284155265
# Running Optuna for Random Forest with PercentilePruner...
# Best MSE for Random Forest with PercentilePruner: 14.559932322520691 with params: {'n_estimators': 200, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}
# Best RMSE for Random Forest with PercentilePruner: 3.815747937498059
# Correlation Coefficient for Random Forest with PercentilePruner: 0.9685747522399442
# Running Optuna for Random Forest with SuccessiveHalvingPruner...
# Best MSE for Random Forest with SuccessiveHalvingPruner: 13.2607369538564 with params: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}
# Best RMSE for Random Forest with SuccessiveHalvingPruner: 3.641529480020229
# Correlation Coefficient for Random Forest with SuccessiveHalvingPruner: 0.970496305061893
# Running Optuna for Random Forest with HyperbandPruner...
# Best MSE for Random Forest with HyperbandPruner: 13.036121626572406 with params: {'n_estimators': 500, 'criterion': 'friedman_mse', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}
# Best RMSE for Random Forest with HyperbandPruner: 3.6105569690246413
# Correlation Coefficient for Random Forest with HyperbandPruner: 0.9708347466886161
# Running Optuna for Random Forest with ThresholdPruner...
# Best MSE for Random Forest with ThresholdPruner: 13.396252070162644 with params: {'n_estimators': 200, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}
# Best RMSE for Random Forest with ThresholdPruner: 3.660089079539273
# Correlation Coefficient for Random Forest with ThresholdPruner: 0.9702838235916544
# Running Optuna for Random Forest with WilcoxonPruner...
# Best MSE for Random Forest with WilcoxonPruner: 13.084370513807446 with params: {'n_estimators': 500, 'criterion': 'squared_error', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}
# Best RMSE for Random Forest with WilcoxonPruner: 3.617232438454494
# Correlation Coefficient for Random Forest with WilcoxonPruner: 0.9707214904398097
# Running Optuna for Gradient Boosting with MedianPruner...
# Best MSE for Gradient Boosting with MedianPruner: 12.153518081628253 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 100, 'subsample': 1.0, 'criterion': 'squared_error', 'min_samples_split': 5, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_depth': 5, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': 'log2', 'alpha': 0.1, 'verbose': 0, 'max_leaf_nodes': 30, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.0001, 'ccp_alpha': 0.01}
# Best RMSE for Gradient Boosting with MedianPruner: 3.4861896221560085
# Correlation Coefficient for Gradient Boosting with MedianPruner: 0.9724739175293039
# Running Optuna for Gradient Boosting with NopPruner...
# Best MSE for Gradient Boosting with NopPruner: 10.28226837491786 with params: {'loss': 'quantile', 'learning_rate': 0.2, 'n_estimators': 500, 'subsample': 0.9, 'criterion': 'squared_error', 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_depth': 5, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': 0.5, 'alpha': 0.5, 'verbose': 0, 'max_leaf_nodes': None, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.0001, 'ccp_alpha': 0.001}
# Best RMSE for Gradient Boosting with NopPruner: 3.206597632213599
# Correlation Coefficient for Gradient Boosting with NopPruner: 0.9770583006149558
# Running Optuna for Gradient Boosting with PatientPruner...
# Best MSE for Gradient Boosting with PatientPruner: 10.855147470416817 with params: {'loss': 'absolute_error', 'learning_rate': 0.2, 'n_estimators': 300, 'subsample': 1.0, 'criterion': 'friedman_mse', 'min_samples_split': 5, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0, 'max_depth': 10, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': 'log2', 'alpha': 0.1, 'verbose': 0, 'max_leaf_nodes': 30, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.0001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with PatientPruner: 3.2947150818267756
# Correlation Coefficient for Gradient Boosting with PatientPruner: 0.9762052044989985
# Running Optuna for Gradient Boosting with PercentilePruner...
# Best MSE for Gradient Boosting with PercentilePruner: 12.227422365513439 with params: {'loss': 'absolute_error', 'learning_rate': 0.1, 'n_estimators': 500, 'subsample': 0.7, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.05, 'max_depth': 3, 'min_impurity_decrease': 0.1, 'init': None, 'random_state': 42, 'max_features': 0.5, 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': None, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with PercentilePruner: 3.49677313612328
# Correlation Coefficient for Gradient Boosting with PercentilePruner: 0.9723282041700549
# Running Optuna for Gradient Boosting with SuccessiveHalvingPruner...
# Best MSE for Gradient Boosting with SuccessiveHalvingPruner: 12.073958499042682 with params: {'loss': 'squared_error', 'learning_rate': 0.01, 'n_estimators': 700, 'subsample': 0.7, 'criterion': 'squared_error', 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_depth': 7, 'min_impurity_decrease': 0.01, 'init': None, 'random_state': 42, 'max_features': 'sqrt', 'alpha': 0.1, 'verbose': 0, 'max_leaf_nodes': None, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with SuccessiveHalvingPruner: 3.4747602074161437
# Correlation Coefficient for Gradient Boosting with SuccessiveHalvingPruner: 0.9729358954453631
# Running Optuna for Gradient Boosting with HyperbandPruner...
# Best MSE for Gradient Boosting with HyperbandPruner: 11.607282355642464 with params: {'loss': 'quantile', 'learning_rate': 0.1, 'n_estimators': 500, 'subsample': 0.7, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_depth': 10, 'min_impurity_decrease': 0.1, 'init': None, 'random_state': 42, 'max_features': None, 'alpha': 0.5, 'verbose': 0, 'max_leaf_nodes': 30, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': 20, 'tol': 0.0001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with HyperbandPruner: 3.4069461920673865
# Correlation Coefficient for Gradient Boosting with HyperbandPruner: 0.9743534450205485
# Running Optuna for Gradient Boosting with ThresholdPruner...
# Best MSE for Gradient Boosting with ThresholdPruner: 12.097951550567178 with params: {'loss': 'huber', 'learning_rate': 0.1, 'n_estimators': 500, 'subsample': 0.7, 'criterion': 'squared_error', 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.0, 'max_depth': 7, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': 'log2', 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': 10, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': 20, 'tol': 0.001, 'ccp_alpha': 0.001}
# Best RMSE for Gradient Boosting with ThresholdPruner: 3.478210969818705
# Correlation Coefficient for Gradient Boosting with ThresholdPruner: 0.9742228783439729
# Running Optuna for Gradient Boosting with WilcoxonPruner...
# Best MSE for Gradient Boosting with WilcoxonPruner: 12.044409277826345 with params: {'loss': 'squared_error', 'learning_rate': 0.2, 'n_estimators': 300, 'subsample': 0.7, 'criterion': 'friedman_mse', 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_depth': 3, 'min_impurity_decrease': 0.1, 'init': None, 'random_state': 42, 'max_features': 0.5, 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': 30, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': 20, 'tol': 0.0001, 'ccp_alpha': 0.001}
# Best RMSE for Gradient Boosting with WilcoxonPruner: 3.4705056227913453
# Correlation Coefficient for Gradient Boosting with WilcoxonPruner: 0.9753417406448451
# Running Optuna for XGBoost with MedianPruner...
# Best MSE for XGBoost with MedianPruner: 12.136811822631739 with params: {'n_estimators': 400, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.1, 'subsample': 0.6, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.9, 'reg_alpha': 0.01, 'reg_lambda': 5, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with MedianPruner: 3.4837927353147373
# Correlation Coefficient for XGBoost with MedianPruner: 0.9726184287908742
# Running Optuna for XGBoost with NopPruner...
# Best MSE for XGBoost with NopPruner: 12.723613138118791 with params: {'n_estimators': 400, 'learning_rate': 0.15, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.1, 'subsample': 0.5, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.7, 'reg_alpha': 0, 'reg_lambda': 10, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with NopPruner: 3.5670174008713205
# Correlation Coefficient for XGBoost with NopPruner: 0.9710061366810492
# Running Optuna for XGBoost with PatientPruner...
# Best MSE for XGBoost with PatientPruner: 12.381260886155815 with params: {'n_estimators': 400, 'learning_rate': 0.15, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 1, 'subsample': 0.5, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.9, 'reg_alpha': 0, 'reg_lambda': 10, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with PatientPruner: 3.5187015909502493
# Correlation Coefficient for XGBoost with PatientPruner: 0.9720178854417231
# Running Optuna for XGBoost with PercentilePruner...
# Best MSE for XGBoost with PercentilePruner: 12.450992778147029 with params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7, 'min_child_weight': 3, 'gamma': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.9, 'reg_alpha': 0, 'reg_lambda': 5, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with PercentilePruner: 3.5285964317483276
# Correlation Coefficient for XGBoost with PercentilePruner: 0.9718237007129169
# Running Optuna for XGBoost with SuccessiveHalvingPruner...
# Best MSE for XGBoost with SuccessiveHalvingPruner: 13.223532782612663 with params: {'n_estimators': 400, 'learning_rate': 0.15, 'max_depth': 7, 'min_child_weight': 3, 'gamma': 1, 'subsample': 0.9, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.5, 'reg_alpha': 1, 'reg_lambda': 0.1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with SuccessiveHalvingPruner: 3.636417575391014
# Correlation Coefficient for XGBoost with SuccessiveHalvingPruner: 0.9709108874636126
# Running Optuna for XGBoost with HyperbandPruner...
# Best MSE for XGBoost with HyperbandPruner: 13.255622907637404 with params: {'n_estimators': 300, 'learning_rate': 0.15, 'max_depth': 7, 'min_child_weight': 1, 'gamma': 0.1, 'subsample': 0.5, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 10, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with HyperbandPruner: 3.640827228479457
# Correlation Coefficient for XGBoost with HyperbandPruner: 0.9701011518752937
# Running Optuna for XGBoost with ThresholdPruner...
# Best MSE for XGBoost with ThresholdPruner: 13.262761390166697 with params: {'n_estimators': 400, 'learning_rate': 0.05, 'max_depth': 7, 'min_child_weight': 3, 'gamma': 0.5, 'subsample': 0.6, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with ThresholdPruner: 3.6418074345257048
# Correlation Coefficient for XGBoost with ThresholdPruner: 0.9706630473686867
# Running Optuna for XGBoost with WilcoxonPruner...
# Best MSE for XGBoost with WilcoxonPruner: 13.177546374116032 with params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 3, 'min_child_weight': 1, 'gamma': 0, 'subsample': 0.9, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 5, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with WilcoxonPruner: 3.6300890311555767
# Correlation Coefficient for XGBoost with WilcoxonPruner: 0.9703781161586259
# Running Optuna for LightGBM with MedianPruner...
# Best MSE for LightGBM with MedianPruner: 10.546189666039878 with params: {'n_estimators': 500, 'learning_rate': 0.01, 'num_leaves': 15, 'max_depth': 7, 'min_child_samples': 5, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 1, 'min_child_weight': 0.001, 'bagging_freq': 0, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with MedianPruner: 3.2474897484118217
# Correlation Coefficient for LightGBM with MedianPruner: 0.9766190579472026
# Running Optuna for LightGBM with NopPruner...
# Best MSE for LightGBM with NopPruner: 10.66684160793602 with params: {'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 63, 'max_depth': 5, 'min_child_samples': 5, 'subsample': 1.0, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 1, 'min_child_weight': 0.01, 'bagging_freq': 0, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with NopPruner: 3.266013105903897
# Correlation Coefficient for LightGBM with NopPruner: 0.9765091625074059
# Running Optuna for LightGBM with PatientPruner...
# Best MSE for LightGBM with PatientPruner: 10.185619350343222 with params: {'n_estimators': 400, 'learning_rate': 0.01, 'num_leaves': 31, 'max_depth': 7, 'min_child_samples': 5, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0.01, 'reg_lambda': 1, 'min_child_weight': 0.01, 'bagging_freq': 0, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with PatientPruner: 3.1914917124039697
# Correlation Coefficient for LightGBM with PatientPruner: 0.9772662645941342
# Running Optuna for LightGBM with PercentilePruner...
# Best MSE for LightGBM with PercentilePruner: 10.537744732143034 with params: {'n_estimators': 300, 'learning_rate': 0.15, 'num_leaves': 15, 'max_depth': 3, 'min_child_samples': 1, 'subsample': 0.5, 'colsample_bytree': 0.9, 'reg_alpha': 0.01, 'reg_lambda': 10, 'min_child_weight': 0.1, 'bagging_freq': 5, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with PercentilePruner: 3.2461892631427136
# Correlation Coefficient for LightGBM with PercentilePruner: 0.9764198711478516
# Running Optuna for LightGBM with SuccessiveHalvingPruner...
# Best MSE for LightGBM with SuccessiveHalvingPruner: 10.884310771235052 with params: {'n_estimators': 500, 'learning_rate': 0.15, 'num_leaves': 31, 'max_depth': 5, 'min_child_samples': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 1, 'min_child_weight': 0.01, 'bagging_freq': 5, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with SuccessiveHalvingPruner: 3.2991378830286937
# Correlation Coefficient for LightGBM with SuccessiveHalvingPruner: 0.9756862577674731
# Running Optuna for LightGBM with HyperbandPruner...
# Best MSE for LightGBM with HyperbandPruner: 10.381542181228612 with params: {'n_estimators': 300, 'learning_rate': 0.05, 'num_leaves': 15, 'max_depth': 7, 'min_child_samples': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 1, 'min_child_weight': 0.001, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with HyperbandPruner: 3.2220400651184664
# Correlation Coefficient for LightGBM with HyperbandPruner: 0.9766964186135217
# Running Optuna for LightGBM with ThresholdPruner...
# Best MSE for LightGBM with ThresholdPruner: 11.469228256528801 with params: {'n_estimators': 400, 'learning_rate': 0.01, 'num_leaves': 15, 'max_depth': 7, 'min_child_samples': 5, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0.01, 'reg_lambda': 0, 'min_child_weight': 0.1, 'bagging_freq': 5, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with ThresholdPruner: 3.386624906382282
# Correlation Coefficient for LightGBM with ThresholdPruner: 0.9743157085118995
# Running Optuna for LightGBM with WilcoxonPruner...
# Best MSE for LightGBM with WilcoxonPruner: 12.201127029952689 with params: {'n_estimators': 300, 'learning_rate': 0.05, 'num_leaves': 15, 'max_depth': -1, 'min_child_samples': 1, 'subsample': 0.7, 'colsample_bytree': 0.5, 'reg_alpha': 0, 'reg_lambda': 0.1, 'min_child_weight': 1e-05, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with WilcoxonPruner: 3.4930111694571906
# Correlation Coefficient for LightGBM with WilcoxonPruner: 0.9730042368458391
# Running Optuna for GPBoost with MedianPruner...
# Best MSE for GPBoost with MedianPruner: 11.093470824663543 with params: {'n_estimators': 400, 'learning_rate': 0.01, 'max_depth': 5, 'num_leaves': 63, 'min_child_samples': 5, 'subsample': 0.6, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 1.0, 'min_child_weight': 1e-05, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with MedianPruner: 3.330686239300175
# Correlation Coefficient for GPBoost with MedianPruner: 0.9754755695476137
# Running Optuna for GPBoost with NopPruner...
# Best MSE for GPBoost with NopPruner: 10.07596275662353 with params: {'n_estimators': 400, 'learning_rate': 0.01, 'max_depth': -1, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 0.6, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 1.0, 'min_child_weight': 1e-05, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with NopPruner: 3.1742657035326345
# Correlation Coefficient for GPBoost with NopPruner: 0.9775981239828208
# Running Optuna for GPBoost with PatientPruner...
# Best MSE for GPBoost with PatientPruner: 10.316675056826002 with params: {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 31, 'min_child_samples': 5, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.0, 'min_child_weight': 0.001, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with PatientPruner: 3.211958134351381
# Correlation Coefficient for GPBoost with PatientPruner: 0.9769829603995179
# Running Optuna for GPBoost with PercentilePruner...
# Best MSE for GPBoost with PercentilePruner: 10.883635849337395 with params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 15, 'min_child_samples': 10, 'subsample': 0.5, 'colsample_bytree': 0.9, 'reg_alpha': 1.0, 'reg_lambda': 0.1, 'min_child_weight': 0.001, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with PercentilePruner: 3.2990355938269893
# Correlation Coefficient for GPBoost with PercentilePruner: 0.975701562397981
# Running Optuna for GPBoost with SuccessiveHalvingPruner...
# Best MSE for GPBoost with SuccessiveHalvingPruner: 10.222401709276937 with params: {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': -1, 'num_leaves': 31, 'min_child_samples': 5, 'subsample': 0.5, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 0.5, 'min_child_weight': 1e-05, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with SuccessiveHalvingPruner: 3.197249084647134
# Correlation Coefficient for GPBoost with SuccessiveHalvingPruner: 0.9772831859837844
# Running Optuna for GPBoost with HyperbandPruner...
# Best MSE for GPBoost with HyperbandPruner: 11.282266380324323 with params: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 5, 'num_leaves': 31, 'min_child_samples': 5, 'subsample': 1.0, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 0.1, 'min_child_weight': 0.001, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with HyperbandPruner: 3.3589085102640595
# Correlation Coefficient for GPBoost with HyperbandPruner: 0.9756924191454851
# Running Optuna for GPBoost with ThresholdPruner...
# Best MSE for GPBoost with ThresholdPruner: 11.119245903100294 with params: {'n_estimators': 300, 'learning_rate': 0.15, 'max_depth': 7, 'num_leaves': 15, 'min_child_samples': 1, 'subsample': 0.6, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 1.0, 'min_child_weight': 0.01, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with ThresholdPruner: 3.3345533288733433
# Correlation Coefficient for GPBoost with ThresholdPruner: 0.9750722001144404
# Running Optuna for GPBoost with WilcoxonPruner...
# Best MSE for GPBoost with WilcoxonPruner: 11.28392806173546 with params: {'n_estimators': 400, 'learning_rate': 0.01, 'max_depth': -1, 'num_leaves': 15, 'min_child_samples': 10, 'subsample': 1.0, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 0.5, 'min_child_weight': 1e-05, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with WilcoxonPruner: 3.359155855529103
# Correlation Coefficient for GPBoost with WilcoxonPruner: 0.9745089392104828
# Running Optuna for CatBoost with MedianPruner...
# Best MSE for CatBoost with MedianPruner: 12.272719969475748 with params: {'iterations': 500, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 32, 'min_data_in_leaf': 1, 'rsm': 0.6, 'bagging_temperature': 10, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with MedianPruner: 3.503244206371538
# Correlation Coefficient for CatBoost with MedianPruner: 0.9726108411638906
# Running Optuna for CatBoost with NopPruner...
# Best MSE for CatBoost with NopPruner: 12.455296163968915 with params: {'iterations': 500, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 9, 'border_count': 32, 'min_data_in_leaf': 10, 'rsm': 0.8, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with NopPruner: 3.5292061662601855
# Correlation Coefficient for CatBoost with NopPruner: 0.9722824968535125
# Running Optuna for CatBoost with PatientPruner...
# Best MSE for CatBoost with PatientPruner: 12.412893712386444 with params: {'iterations': 200, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 32, 'min_data_in_leaf': 1, 'rsm': 0.6, 'bagging_temperature': 0, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with PatientPruner: 3.5231936807939532
# Correlation Coefficient for CatBoost with PatientPruner: 0.9723833874013228
# Running Optuna for CatBoost with PercentilePruner...
# Best MSE for CatBoost with PercentilePruner: 11.855218020554956 with params: {'iterations': 500, 'learning_rate': 0.03, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 32, 'min_data_in_leaf': 20, 'rsm': 0.8, 'bagging_temperature': 0, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with PercentilePruner: 3.443140720411374
# Correlation Coefficient for CatBoost with PercentilePruner: 0.9736540447216337
# Running Optuna for CatBoost with SuccessiveHalvingPruner...
# Best MSE for CatBoost with SuccessiveHalvingPruner: 10.919798187835573 with params: {'iterations': 200, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 32, 'min_data_in_leaf': 1, 'rsm': 1.0, 'bagging_temperature': 10, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with SuccessiveHalvingPruner: 3.3045117926609935
# Correlation Coefficient for CatBoost with SuccessiveHalvingPruner: 0.9763196998303095
# Running Optuna for CatBoost with HyperbandPruner...
# Best MSE for CatBoost with HyperbandPruner: 11.942747714870922 with params: {'iterations': 500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 7, 'border_count': 128, 'min_data_in_leaf': 10, 'rsm': 0.6, 'bagging_temperature': 0, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with HyperbandPruner: 3.4558280794725484
# Correlation Coefficient for CatBoost with HyperbandPruner: 0.9733039847347529
# Running Optuna for CatBoost with ThresholdPruner...
# Best MSE for CatBoost with ThresholdPruner: 11.08404516153846 with params: {'iterations': 500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 32, 'min_data_in_leaf': 10, 'rsm': 1.0, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with ThresholdPruner: 3.3292709654725403
# Correlation Coefficient for CatBoost with ThresholdPruner: 0.9759763178694743
# Running Optuna for CatBoost with WilcoxonPruner...
# Best MSE for CatBoost with WilcoxonPruner: 12.260759760587039 with params: {'iterations': 500, 'learning_rate': 0.03, 'depth': 8, 'l2_leaf_reg': 7, 'border_count': 32, 'min_data_in_leaf': 10, 'rsm': 0.8, 'bagging_temperature': 0, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with WilcoxonPruner: 3.5015367712744414
# Correlation Coefficient for CatBoost with WilcoxonPruner: 0.9729419180582299
# Running Optuna for NGBoost with MedianPruner...
# Best MSE for NGBoost with MedianPruner: 12.988271035439867 with params: {'n_estimators': 500, 'learning_rate': 0.03, 'natural_gradient': True, 'minibatch_frac': 0.7, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with MedianPruner: 3.603924393690837
# Correlation Coefficient for NGBoost with MedianPruner: 0.9710197025716992
# Running Optuna for NGBoost with NopPruner...
# Best MSE for NGBoost with NopPruner: 13.335517008968388 with params: {'n_estimators': 500, 'learning_rate': 0.03, 'natural_gradient': True, 'minibatch_frac': 0.7, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with NopPruner: 3.651782716560281
# Correlation Coefficient for NGBoost with NopPruner: 0.9698560099630124
# Running Optuna for NGBoost with PatientPruner...
# Best MSE for NGBoost with PatientPruner: 14.597899752729637 with params: {'n_estimators': 1000, 'learning_rate': 0.05, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 1.0, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with PatientPruner: 3.8207197951079372
# Correlation Coefficient for NGBoost with PatientPruner: 0.9669288311765937
# Running Optuna for NGBoost with PercentilePruner...
# Best MSE for NGBoost with PercentilePruner: 12.83715509365134 with params: {'n_estimators': 200, 'learning_rate': 0.03, 'natural_gradient': True, 'minibatch_frac': 0.7, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with PercentilePruner: 3.582897583472257
# Correlation Coefficient for NGBoost with PercentilePruner: 0.9709457051145279
# Running Optuna for NGBoost with SuccessiveHalvingPruner...
# Best MSE for NGBoost with SuccessiveHalvingPruner: 12.452832352634385 with params: {'n_estimators': 1000, 'learning_rate': 0.03, 'natural_gradient': True, 'minibatch_frac': 0.7, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with SuccessiveHalvingPruner: 3.528857088723541
# Correlation Coefficient for NGBoost with SuccessiveHalvingPruner: 0.9716987675973743
# Running Optuna for NGBoost with HyperbandPruner...
# Best MSE for NGBoost with HyperbandPruner: 13.098905683055307 with params: {'n_estimators': 500, 'learning_rate': 0.03, 'natural_gradient': True, 'minibatch_frac': 0.7, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with HyperbandPruner: 3.619241036882637
# Correlation Coefficient for NGBoost with HyperbandPruner: 0.9703003692092006
# Running Optuna for NGBoost with ThresholdPruner...
# Best MSE for NGBoost with ThresholdPruner: 12.035903691269185 with params: {'n_estimators': 200, 'learning_rate': 0.03, 'natural_gradient': True, 'minibatch_frac': 0.7, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with ThresholdPruner: 3.4692799960898495
# Correlation Coefficient for NGBoost with ThresholdPruner: 0.9728649028395556
# Running Optuna for NGBoost with WilcoxonPruner...
# Best MSE for NGBoost with WilcoxonPruner: 12.667599761291468 with params: {'n_estimators': 200, 'learning_rate': 0.03, 'natural_gradient': True, 'minibatch_frac': 0.7, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with WilcoxonPruner: 3.559157170074324
# Correlation Coefficient for NGBoost with WilcoxonPruner: 0.9715007054198
# Running Optuna for HistGradientBoosting with MedianPruner...
# Best MSE for HistGradientBoosting with MedianPruner: 10.471840797020173 with params: {'learning_rate': 0.05, 'max_iter': 400, 'max_depth': None, 'min_samples_leaf': 10, 'max_leaf_nodes': None, 'l2_regularization': 1.0, 'max_bins': 64, 'early_stopping': True, 'validation_fraction': 0.1, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with MedianPruner: 3.236022372762613
# Correlation Coefficient for HistGradientBoosting with MedianPruner: 0.9766586844671373
# Running Optuna for HistGradientBoosting with NopPruner...
# Best MSE for HistGradientBoosting with NopPruner: 12.073827638061124 with params: {'learning_rate': 0.01, 'max_iter': 400, 'max_depth': None, 'min_samples_leaf': 10, 'max_leaf_nodes': 15, 'l2_regularization': 1.0, 'max_bins': 128, 'early_stopping': False, 'validation_fraction': 0.1, 'n_iter_no_change': 5, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with NopPruner: 3.4747413771475313
# Correlation Coefficient for HistGradientBoosting with NopPruner: 0.9727068556280255
# Running Optuna for HistGradientBoosting with PatientPruner...
# Best MSE for HistGradientBoosting with PatientPruner: 10.292353900564587 with params: {'learning_rate': 0.05, 'max_iter': 500, 'max_depth': None, 'min_samples_leaf': 10, 'max_leaf_nodes': None, 'l2_regularization': 0.5, 'max_bins': 64, 'early_stopping': True, 'validation_fraction': 0.1, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with PatientPruner: 3.20816986778515
# Correlation Coefficient for HistGradientBoosting with PatientPruner: 0.9771500387696429
# Running Optuna for HistGradientBoosting with PercentilePruner...
# Best MSE for HistGradientBoosting with PercentilePruner: 10.392964120061412 with params: {'learning_rate': 0.05, 'max_iter': 300, 'max_depth': 5, 'min_samples_leaf': 10, 'max_leaf_nodes': 15, 'l2_regularization': 0.0, 'max_bins': 64, 'early_stopping': True, 'validation_fraction': 0.1, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with PercentilePruner: 3.223812047880802
# Correlation Coefficient for HistGradientBoosting with PercentilePruner: 0.9769099995945186
# Running Optuna for HistGradientBoosting with SuccessiveHalvingPruner...
# Best MSE for HistGradientBoosting with SuccessiveHalvingPruner: 12.738329871653146 with params: {'learning_rate': 0.01, 'max_iter': 300, 'max_depth': None, 'min_samples_leaf': 5, 'max_leaf_nodes': 31, 'l2_regularization': 1.0, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.1, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with SuccessiveHalvingPruner: 3.5690796953350796
# Correlation Coefficient for HistGradientBoosting with SuccessiveHalvingPruner: 0.9729987904189179
# Running Optuna for HistGradientBoosting with HyperbandPruner...
# Best MSE for HistGradientBoosting with HyperbandPruner: 12.738329871653146 with params: {'learning_rate': 0.01, 'max_iter': 300, 'max_depth': None, 'min_samples_leaf': 5, 'max_leaf_nodes': 31, 'l2_regularization': 1.0, 'max_bins': 128, 'early_stopping': False, 'validation_fraction': 0.2, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with HyperbandPruner: 3.5690796953350796
# Correlation Coefficient for HistGradientBoosting with HyperbandPruner: 0.9729987904189179
# Running Optuna for HistGradientBoosting with ThresholdPruner...
# Best MSE for HistGradientBoosting with ThresholdPruner: 10.292353900564587 with params: {'learning_rate': 0.05, 'max_iter': 300, 'max_depth': None, 'min_samples_leaf': 10, 'max_leaf_nodes': 15, 'l2_regularization': 0.5, 'max_bins': 64, 'early_stopping': True, 'validation_fraction': 0.1, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with ThresholdPruner: 3.20816986778515
# Correlation Coefficient for HistGradientBoosting with ThresholdPruner: 0.9771500387696429
# Running Optuna for HistGradientBoosting with WilcoxonPruner...
# Best MSE for HistGradientBoosting with WilcoxonPruner: 10.292353900564587 with params: {'learning_rate': 0.05, 'max_iter': 200, 'max_depth': None, 'min_samples_leaf': 10, 'max_leaf_nodes': 63, 'l2_regularization': 0.5, 'max_bins': 64, 'early_stopping': True, 'validation_fraction': 0.1, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with WilcoxonPruner: 3.20816986778515
# Correlation Coefficient for HistGradientBoosting with WilcoxonPruner: 0.9771500387696429
# Running Optuna for PGBM with MedianPruner...
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Estimator 0/100, Train metric: 13.1307
# Estimator 1/100, Train metric: 12.1487
# Estimator 2/100, Train metric: 11.2906
# Estimator 3/100, Train metric: 10.5150
# Estimator 4/100, Train metric: 9.7844
# Estimator 5/100, Train metric: 9.1281
# Estimator 6/100, Train metric: 8.4884
# Estimator 7/100, Train metric: 7.9268
# Estimator 8/100, Train metric: 7.4233
# Estimator 9/100, Train metric: 6.9822
# Estimator 10/100, Train metric: 6.5890
# Estimator 11/100, Train metric: 6.2122
# Estimator 12/100, Train metric: 5.8753
# Estimator 13/100, Train metric: 5.5914
# Estimator 14/100, Train metric: 5.2972
# Estimator 15/100, Train metric: 5.0443
# Estimator 16/100, Train metric: 4.7837
# Estimator 17/100, Train metric: 4.5576
# Estimator 18/100, Train metric: 4.3465
# Estimator 19/100, Train metric: 4.1505
# Estimator 20/100, Train metric: 4.0010
# Estimator 21/100, Train metric: 3.8187
# Estimator 22/100, Train metric: 3.6722
# Estimator 23/100, Train metric: 3.5362
# Estimator 24/100, Train metric: 3.4289
# Estimator 25/100, Train metric: 3.3260
# Estimator 26/100, Train metric: 3.2028
# Estimator 27/100, Train metric: 3.0926
# Estimator 28/100, Train metric: 2.9983
# Estimator 29/100, Train metric: 2.9171
# Estimator 30/100, Train metric: 2.8533
# Estimator 31/100, Train metric: 2.7842
# Estimator 32/100, Train metric: 2.7016
# Estimator 33/100, Train metric: 2.6251
# Estimator 34/100, Train metric: 2.5513
# Estimator 35/100, Train metric: 2.4956
# Estimator 36/100, Train metric: 2.4388
# Estimator 37/100, Train metric: 2.3820
# Estimator 38/100, Train metric: 2.3370
# Estimator 39/100, Train metric: 2.2767
# Estimator 40/100, Train metric: 2.2322
# Estimator 41/100, Train metric: 2.1837
# Estimator 42/100, Train metric: 2.1388
# Estimator 43/100, Train metric: 2.1082
# Estimator 44/100, Train metric: 2.0713
# Estimator 45/100, Train metric: 2.0378
# Estimator 46/100, Train metric: 1.9884
# Estimator 47/100, Train metric: 1.9583
# Estimator 48/100, Train metric: 1.9272
# Estimator 49/100, Train metric: 1.9034
# Estimator 50/100, Train metric: 1.8730
# Estimator 51/100, Train metric: 1.8440
# Estimator 52/100, Train metric: 1.8219
# Estimator 53/100, Train metric: 1.7993
# Estimator 54/100, Train metric: 1.7832
# Estimator 55/100, Train metric: 1.7624
# Estimator 56/100, Train metric: 1.7469
# Estimator 57/100, Train metric: 1.7248
# Estimator 58/100, Train metric: 1.7053
# Estimator 59/100, Train metric: 1.6848
# Estimator 60/100, Train metric: 1.6685
# Estimator 61/100, Train metric: 1.6411
# Estimator 62/100, Train metric: 1.6099
# Estimator 63/100, Train metric: 1.5920
# Estimator 64/100, Train metric: 1.5782
# Estimator 65/100, Train metric: 1.5641
# Estimator 66/100, Train metric: 1.5475
# Estimator 67/100, Train metric: 1.5216
# Estimator 68/100, Train metric: 1.5088
# Estimator 69/100, Train metric: 1.4894
# Estimator 70/100, Train metric: 1.4783
# Estimator 71/100, Train metric: 1.4691
# Estimator 72/100, Train metric: 1.4534
# Estimator 73/100, Train metric: 1.4381
# Estimator 74/100, Train metric: 1.4163
# Estimator 75/100, Train metric: 1.3975
# Estimator 76/100, Train metric: 1.3870
# Estimator 77/100, Train metric: 1.3774
# Estimator 78/100, Train metric: 1.3672
# Estimator 79/100, Train metric: 1.3527
# Estimator 80/100, Train metric: 1.3335
# Estimator 81/100, Train metric: 1.3230
# Estimator 82/100, Train metric: 1.3080
# Estimator 83/100, Train metric: 1.2952
# Estimator 84/100, Train metric: 1.2755
# Estimator 85/100, Train metric: 1.2537
# Estimator 86/100, Train metric: 1.2430
# Estimator 87/100, Train metric: 1.2361
# Estimator 88/100, Train metric: 1.2194
# Estimator 89/100, Train metric: 1.2057
# Estimator 90/100, Train metric: 1.1980
# Estimator 91/100, Train metric: 1.1888
# Estimator 92/100, Train metric: 1.1817
# Estimator 93/100, Train metric: 1.1700
# Estimator 94/100, Train metric: 1.1589
# Estimator 95/100, Train metric: 1.1523
# Estimator 96/100, Train metric: 1.1421
# Estimator 97/100, Train metric: 1.1350
# Estimator 98/100, Train metric: 1.1256
# Estimator 99/100, Train metric: 1.1200
# Best MSE for PGBM with MedianPruner: 15.171240778431299 with params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_leaves': 63, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 64, 'distribution': 'studentt'}
# Best RMSE for PGBM with MedianPruner: 3.8950276993150252
# Correlation Coefficient for PGBM with MedianPruner: 0.9673690326713885
# Running Optuna for PGBM with NopPruner...
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Estimator 0/100, Train metric: 13.2555
# Estimator 1/100, Train metric: 12.3869
# Estimator 2/100, Train metric: 11.6185
# Estimator 3/100, Train metric: 10.9143
# Estimator 4/100, Train metric: 10.2504
# Estimator 5/100, Train metric: 9.6450
# Estimator 6/100, Train metric: 9.0505
# Estimator 7/100, Train metric: 8.5297
# Estimator 8/100, Train metric: 8.0441
# Estimator 9/100, Train metric: 7.6162
# Estimator 10/100, Train metric: 7.2310
# Estimator 11/100, Train metric: 6.8730
# Estimator 12/100, Train metric: 6.5384
# Estimator 13/100, Train metric: 6.2360
# Estimator 14/100, Train metric: 5.9508
# Estimator 15/100, Train metric: 5.6843
# Estimator 16/100, Train metric: 5.4340
# Estimator 17/100, Train metric: 5.2124
# Estimator 18/100, Train metric: 5.0058
# Estimator 19/100, Train metric: 4.8132
# Estimator 20/100, Train metric: 4.6641
# Estimator 21/100, Train metric: 4.4764
# Estimator 22/100, Train metric: 4.3275
# Estimator 23/100, Train metric: 4.1939
# Estimator 24/100, Train metric: 4.0771
# Estimator 25/100, Train metric: 3.9633
# Estimator 26/100, Train metric: 3.8481
# Estimator 27/100, Train metric: 3.7255
# Estimator 28/100, Train metric: 3.6228
# Estimator 29/100, Train metric: 3.5271
# Estimator 30/100, Train metric: 3.4500
# Estimator 31/100, Train metric: 3.3712
# Estimator 32/100, Train metric: 3.2928
# Estimator 33/100, Train metric: 3.2170
# Estimator 34/100, Train metric: 3.1483
# Estimator 35/100, Train metric: 3.0931
# Estimator 36/100, Train metric: 3.0255
# Estimator 37/100, Train metric: 2.9687
# Estimator 38/100, Train metric: 2.9074
# Estimator 39/100, Train metric: 2.8469
# Estimator 40/100, Train metric: 2.8071
# Estimator 41/100, Train metric: 2.7546
# Estimator 42/100, Train metric: 2.7037
# Estimator 43/100, Train metric: 2.6694
# Estimator 44/100, Train metric: 2.6338
# Estimator 45/100, Train metric: 2.5959
# Estimator 46/100, Train metric: 2.5533
# Estimator 47/100, Train metric: 2.5151
# Estimator 48/100, Train metric: 2.4677
# Estimator 49/100, Train metric: 2.4430
# Estimator 50/100, Train metric: 2.4127
# Estimator 51/100, Train metric: 2.3787
# Estimator 52/100, Train metric: 2.3573
# Estimator 53/100, Train metric: 2.3297
# Estimator 54/100, Train metric: 2.3087
# Estimator 55/100, Train metric: 2.2817
# Estimator 56/100, Train metric: 2.2600
# Estimator 57/100, Train metric: 2.2383
# Estimator 58/100, Train metric: 2.2105
# Estimator 59/100, Train metric: 2.1926
# Estimator 60/100, Train metric: 2.1713
# Estimator 61/100, Train metric: 2.1312
# Estimator 62/100, Train metric: 2.0940
# Estimator 63/100, Train metric: 2.0678
# Estimator 64/100, Train metric: 2.0465
# Estimator 65/100, Train metric: 2.0218
# Estimator 66/100, Train metric: 2.0028
# Estimator 67/100, Train metric: 1.9783
# Estimator 68/100, Train metric: 1.9651
# Estimator 69/100, Train metric: 1.9363
# Estimator 70/100, Train metric: 1.9163
# Estimator 71/100, Train metric: 1.9068
# Estimator 72/100, Train metric: 1.8884
# Estimator 73/100, Train metric: 1.8698
# Estimator 74/100, Train metric: 1.8470
# Estimator 75/100, Train metric: 1.8267
# Estimator 76/100, Train metric: 1.8141
# Estimator 77/100, Train metric: 1.8038
# Estimator 78/100, Train metric: 1.7914
# Estimator 79/100, Train metric: 1.7765
# Estimator 80/100, Train metric: 1.7568
# Estimator 81/100, Train metric: 1.7409
# Estimator 82/100, Train metric: 1.7299
# Estimator 83/100, Train metric: 1.7130
# Estimator 84/100, Train metric: 1.7025
# Estimator 85/100, Train metric: 1.6846
# Estimator 86/100, Train metric: 1.6741
# Estimator 87/100, Train metric: 1.6619
# Estimator 88/100, Train metric: 1.6475
# Estimator 89/100, Train metric: 1.6334
# Estimator 90/100, Train metric: 1.6180
# Estimator 91/100, Train metric: 1.6087
# Estimator 92/100, Train metric: 1.5979
# Estimator 93/100, Train metric: 1.5877
# Estimator 94/100, Train metric: 1.5791
# Estimator 95/100, Train metric: 1.5671
# Estimator 96/100, Train metric: 1.5549
# Estimator 97/100, Train metric: 1.5458
# Estimator 98/100, Train metric: 1.5385
# Estimator 99/100, Train metric: 1.5327
# Best MSE for PGBM with NopPruner: 15.623112163352925 with params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_leaves': 31, 'min_split_gain': 0.5, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.3, 'min_data_in_leaf': 5, 'max_bin': 64, 'distribution': 'studentt'}
# Best RMSE for PGBM with NopPruner: 3.952608273450953
# Correlation Coefficient for PGBM with NopPruner: 0.9666119657338578
# Running Optuna for PGBM with PatientPruner...
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Estimator 0/300, Train metric: 13.3241
# Estimator 1/300, Train metric: 12.5260
# Estimator 2/300, Train metric: 11.8822
# Estimator 3/300, Train metric: 11.1845
# Estimator 4/300, Train metric: 10.5264
# Estimator 5/300, Train metric: 10.0384
# Estimator 6/300, Train metric: 9.5847
# Estimator 7/300, Train metric: 9.1164
# Estimator 8/300, Train metric: 8.6951
# ...
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Estimator 0/100, Train metric: 12.6415
# Estimator 1/100, Train metric: 11.3057
# Estimator 2/100, Train metric: 10.2784
# Estimator 3/100, Train metric: 9.2705
# Estimator 4/100, Train metric: 8.3543
# Estimator 5/100, Train metric: 7.6669
# Estimator 6/100, Train metric: 7.1006
# Estimator 7/100, Train metric: 6.5381
# Estimator 8/100, Train metric: 6.0960
# Estimator 9/100, Train metric: 5.6297
# Estimator 10/100, Train metric: 5.3130
# Estimator 11/100, Train metric: 4.9761
# Estimator 12/100, Train metric: 4.7338
# Estimator 13/100, Train metric: 4.4393
# Estimator 14/100, Train metric: 4.2290
# Estimator 15/100, Train metric: 4.0420
# Estimator 16/100, Train metric: 3.8913
# Estimator 17/100, Train metric: 3.7274
# Estimator 18/100, Train metric: 3.5709
# Estimator 19/100, Train metric: 3.4123
# Estimator 20/100, Train metric: 3.2570
# Estimator 21/100, Train metric: 3.1779
# Estimator 22/100, Train metric: 3.0940
# Estimator 23/100, Train metric: 3.0089
# Estimator 24/100, Train metric: 2.9195
# Estimator 25/100, Train metric: 2.8668
# Estimator 26/100, Train metric: 2.8289
# Estimator 27/100, Train metric: 2.7721
# Estimator 28/100, Train metric: 2.6979
# Estimator 29/100, Train metric: 2.6441
# Estimator 30/100, Train metric: 2.6103
# Estimator 31/100, Train metric: 2.5556
# Estimator 32/100, Train metric: 2.4909
# Estimator 33/100, Train metric: 2.4580
# Estimator 34/100, Train metric: 2.4284
# Estimator 35/100, Train metric: 2.3873
# Estimator 36/100, Train metric: 2.2961
# Estimator 37/100, Train metric: 2.2564
# Estimator 38/100, Train metric: 2.1926
# Estimator 39/100, Train metric: 2.1702
# Estimator 40/100, Train metric: 2.1380
# Estimator 41/100, Train metric: 2.0733
# Estimator 42/100, Train metric: 2.0401
# Estimator 43/100, Train metric: 1.9926
# Estimator 44/100, Train metric: 1.9701
# Estimator 45/100, Train metric: 1.9513
# Estimator 46/100, Train metric: 1.9225
# Estimator 47/100, Train metric: 1.8908
# Estimator 48/100, Train metric: 1.8502
# Estimator 49/100, Train metric: 1.8372
# Estimator 50/100, Train metric: 1.8169
# Estimator 51/100, Train metric: 1.7880
# Estimator 52/100, Train metric: 1.7650
# Estimator 53/100, Train metric: 1.7459
# Estimator 54/100, Train metric: 1.7350
# Estimator 55/100, Train metric: 1.7139
# Estimator 56/100, Train metric: 1.6905
# Estimator 57/100, Train metric: 1.6787
# Estimator 58/100, Train metric: 1.6584
# Estimator 59/100, Train metric: 1.6369
# Estimator 60/100, Train metric: 1.6175
# Estimator 61/100, Train metric: 1.6073
# Estimator 62/100, Train metric: 1.5765
# Estimator 63/100, Train metric: 1.5740
# Estimator 64/100, Train metric: 1.5636
# Estimator 65/100, Train metric: 1.5398
# Estimator 66/100, Train metric: 1.5282
# Estimator 67/100, Train metric: 1.5068
# Estimator 68/100, Train metric: 1.5007
# Estimator 69/100, Train metric: 1.4797
# Estimator 70/100, Train metric: 1.4816
# Estimator 71/100, Train metric: 1.4698
# Estimator 72/100, Train metric: 1.4586
# Estimator 73/100, Train metric: 1.4392
# Estimator 74/100, Train metric: 1.4277
# Estimator 75/100, Train metric: 1.4096
# Estimator 76/100, Train metric: 1.4064
# Estimator 77/100, Train metric: 1.3996
# Estimator 78/100, Train metric: 1.3853
# Estimator 79/100, Train metric: 1.3579
# Estimator 80/100, Train metric: 1.3394
# Estimator 81/100, Train metric: 1.3281
# Estimator 82/100, Train metric: 1.3147
# Estimator 83/100, Train metric: 1.2973
# Estimator 84/100, Train metric: 1.2785
# Estimator 85/100, Train metric: 1.2732
# Estimator 86/100, Train metric: 1.2543
# Estimator 87/100, Train metric: 1.2452
# Estimator 88/100, Train metric: 1.2287
# Estimator 89/100, Train metric: 1.2246
# Estimator 90/100, Train metric: 1.2125
# Estimator 91/100, Train metric: 1.1983
# Estimator 92/100, Train metric: 1.1772
# Estimator 93/100, Train metric: 1.1714
# Estimator 94/100, Train metric: 1.1652
# Estimator 95/100, Train metric: 1.1515
# Estimator 96/100, Train metric: 1.1413
# Estimator 97/100, Train metric: 1.1347
# Estimator 98/100, Train metric: 1.1262
# Estimator 99/100, Train metric: 1.1127
# Best MSE for PGBM with HyperbandPruner: 14.46691883448201 with params: {'n_estimators': 100, 'learning_rate': 0.15, 'max_leaves': 31, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.5, 'tree_correlation': 0.1, 'min_data_in_leaf': 3, 'max_bin': 256, 'distribution': 'normal'}
# Best RMSE for PGBM with HyperbandPruner: 3.803540302728763
# Correlation Coefficient for PGBM with HyperbandPruner: 0.9693321886495186
# Running Optuna for PGBM with ThresholdPruner...
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Estimator 0/100, Train metric: 13.6632
# Estimator 1/100, Train metric: 13.1462
# Estimator 2/100, Train metric: 12.6734
# Estimator 3/100, Train metric: 12.2236
# Estimator 4/100, Train metric: 11.7795
# Estimator 5/100, Train metric: 11.3619
# Estimator 6/100, Train metric: 10.9367
# Estimator 7/100, Train metric: 10.5444
# Estimator 8/100, Train metric: 10.1656
# Estimator 9/100, Train metric: 9.8201
# Estimator 10/100, Train metric: 9.5004
# Estimator 11/100, Train metric: 9.1969
# Estimator 12/100, Train metric: 8.8946
# Estimator 13/100, Train metric: 8.6149
# Estimator 14/100, Train metric: 8.3280
# Estimator 15/100, Train metric: 8.0704
# Estimator 16/100, Train metric: 7.8149
# Estimator 17/100, Train metric: 7.5736
# Estimator 18/100, Train metric: 7.3279
# Estimator 19/100, Train metric: 7.0980
# Estimator 20/100, Train metric: 6.8991
# Estimator 21/100, Train metric: 6.6986
# Estimator 22/100, Train metric: 6.5032
# Estimator 23/100, Train metric: 6.3197
# Estimator 24/100, Train metric: 6.1399
# Estimator 25/100, Train metric: 5.9741
# Estimator 26/100, Train metric: 5.8092
# Estimator 27/100, Train metric: 5.6474
# Estimator 28/100, Train metric: 5.4987
# Estimator 29/100, Train metric: 5.3501
# Estimator 30/100, Train metric: 5.2144
# Estimator 31/100, Train metric: 5.0742
# Estimator 32/100, Train metric: 4.9519
# Estimator 33/100, Train metric: 4.8322
# Estimator 34/100, Train metric: 4.7254
# Estimator 35/100, Train metric: 4.6134
# Estimator 36/100, Train metric: 4.5147
# Estimator 37/100, Train metric: 4.4096
# Estimator 38/100, Train metric: 4.3082
# Estimator 39/100, Train metric: 4.2057
# Estimator 40/100, Train metric: 4.1239
# Estimator 41/100, Train metric: 4.0405
# Estimator 42/100, Train metric: 3.9511
# Estimator 43/100, Train metric: 3.8779
# Estimator 44/100, Train metric: 3.8098
# Estimator 45/100, Train metric: 3.7315
# Estimator 46/100, Train metric: 3.6585
# Estimator 47/100, Train metric: 3.5854
# Estimator 48/100, Train metric: 3.5215
# Estimator 49/100, Train metric: 3.4603
# Estimator 50/100, Train metric: 3.4006
# Estimator 51/100, Train metric: 3.3464
# Estimator 52/100, Train metric: 3.2903
# Estimator 53/100, Train metric: 3.2448
# Estimator 54/100, Train metric: 3.2048
# Estimator 55/100, Train metric: 3.1564
# Estimator 56/100, Train metric: 3.1122
# Estimator 57/100, Train metric: 3.0621
# Estimator 58/100, Train metric: 3.0130
# Estimator 59/100, Train metric: 2.9719
# Estimator 60/100, Train metric: 2.9326
# Estimator 61/100, Train metric: 2.8904
# Estimator 62/100, Train metric: 2.8522
# Estimator 63/100, Train metric: 2.8174
# Estimator 64/100, Train metric: 2.7848
# Estimator 65/100, Train metric: 2.7466
# Estimator 66/100, Train metric: 2.7107
# Estimator 67/100, Train metric: 2.6765
# Estimator 68/100, Train metric: 2.6487
# Estimator 69/100, Train metric: 2.6148
# Estimator 70/100, Train metric: 2.5849
# Estimator 71/100, Train metric: 2.5587
# Estimator 72/100, Train metric: 2.5274
# Estimator 73/100, Train metric: 2.4996
# Estimator 74/100, Train metric: 2.4734
# Estimator 75/100, Train metric: 2.4453
# Estimator 76/100, Train metric: 2.4240
# Estimator 77/100, Train metric: 2.4118
# Estimator 78/100, Train metric: 2.3848
# Estimator 79/100, Train metric: 2.3643
# Estimator 80/100, Train metric: 2.3405
# Estimator 81/100, Train metric: 2.3225
# Estimator 82/100, Train metric: 2.3085
# Estimator 83/100, Train metric: 2.2871
# Estimator 84/100, Train metric: 2.2689
# Estimator 85/100, Train metric: 2.2412
# Estimator 86/100, Train metric: 2.2265
# Estimator 87/100, Train metric: 2.2044
# Estimator 88/100, Train metric: 2.1775
# Estimator 89/100, Train metric: 2.1551
# Estimator 90/100, Train metric: 2.1337
# Estimator 91/100, Train metric: 2.1153
# Estimator 92/100, Train metric: 2.0946
# Estimator 93/100, Train metric: 2.0768
# Estimator 94/100, Train metric: 2.0621
# Estimator 95/100, Train metric: 2.0496
# Estimator 96/100, Train metric: 2.0351
# Estimator 97/100, Train metric: 2.0214
# Estimator 98/100, Train metric: 2.0097
# Estimator 99/100, Train metric: 1.9968
# Best MSE for PGBM with ThresholdPruner: 15.893417514351563 with params: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 48, 'min_split_gain': 1.0, 'reg_lambda': 5.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.0, 'min_data_in_leaf': 5, 'max_bin': 64, 'distribution': 'studentt'}
# Best RMSE for PGBM with ThresholdPruner: 3.9866549279253607
# Correlation Coefficient for PGBM with ThresholdPruner: 0.9679821523563314
# Running Optuna for PGBM with WilcoxonPruner...
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Estimator 0/100, Train metric: 13.1271
# Estimator 1/100, Train metric: 12.1421
# Estimator 2/100, Train metric: 11.3423
# Estimator 3/100, Train metric: 10.5391
# Estimator 4/100, Train metric: 9.8056
# Estimator 5/100, Train metric: 9.1249
# Estimator 6/100, Train metric: 8.5282
# Estimator 7/100, Train metric: 7.9806
# Estimator 8/100, Train metric: 7.4893
# Estimator 9/100, Train metric: 7.0556
# Estimator 10/100, Train metric: 6.6935
# Estimator 11/100, Train metric: 6.3372
# Estimator 12/100, Train metric: 6.0001
# Estimator 13/100, Train metric: 5.6675
# Estimator 14/100, Train metric: 5.3970
# Estimator 15/100, Train metric: 5.1675
# Estimator 16/100, Train metric: 4.9311
# Estimator 17/100, Train metric: 4.6986
# Estimator 18/100, Train metric: 4.4750
# Estimator 19/100, Train metric: 4.2683
# Estimator 20/100, Train metric: 4.1104
# Estimator 21/100, Train metric: 3.9353
# Estimator 22/100, Train metric: 3.7839
# Estimator 23/100, Train metric: 3.6444
# Estimator 24/100, Train metric: 3.5348
# Estimator 25/100, Train metric: 3.4277
# Estimator 26/100, Train metric: 3.3125
# Estimator 27/100, Train metric: 3.2142
# Estimator 28/100, Train metric: 3.1093
# Estimator 29/100, Train metric: 3.0202
# Estimator 30/100, Train metric: 2.9610
# Estimator 31/100, Train metric: 2.8749
# Estimator 32/100, Train metric: 2.7917
# Estimator 33/100, Train metric: 2.7173
# Estimator 34/100, Train metric: 2.6422
# Estimator 35/100, Train metric: 2.5855
# Estimator 36/100, Train metric: 2.5041
# Estimator 37/100, Train metric: 2.4428
# Estimator 38/100, Train metric: 2.3782
# Estimator 39/100, Train metric: 2.3280
# Estimator 40/100, Train metric: 2.2887
# Estimator 41/100, Train metric: 2.2347
# Estimator 42/100, Train metric: 2.1872
# Estimator 43/100, Train metric: 2.1401
# Estimator 44/100, Train metric: 2.1148
# Estimator 45/100, Train metric: 2.0748
# Estimator 46/100, Train metric: 2.0429
# Estimator 47/100, Train metric: 2.0120
# Estimator 48/100, Train metric: 1.9789
# Estimator 49/100, Train metric: 1.9535
# Estimator 50/100, Train metric: 1.9078
# Estimator 51/100, Train metric: 1.8624
# Estimator 52/100, Train metric: 1.8386
# Estimator 53/100, Train metric: 1.8152
# Estimator 54/100, Train metric: 1.7953
# Estimator 55/100, Train metric: 1.7657
# Estimator 56/100, Train metric: 1.7407
# Estimator 57/100, Train metric: 1.7160
# Estimator 58/100, Train metric: 1.6949
# Estimator 59/100, Train metric: 1.6787
# Estimator 60/100, Train metric: 1.6568
# Estimator 61/100, Train metric: 1.6415
# Estimator 62/100, Train metric: 1.6088
# Estimator 63/100, Train metric: 1.5992
# Estimator 64/100, Train metric: 1.5863
# Estimator 65/100, Train metric: 1.5697
# Estimator 66/100, Train metric: 1.5445
# Estimator 67/100, Train metric: 1.5181
# Estimator 68/100, Train metric: 1.5082
# Estimator 69/100, Train metric: 1.4901
# Estimator 70/100, Train metric: 1.4761
# Estimator 71/100, Train metric: 1.4583
# Estimator 72/100, Train metric: 1.4448
# Estimator 73/100, Train metric: 1.4336
# Estimator 74/100, Train metric: 1.4146
# Estimator 75/100, Train metric: 1.3976
# Estimator 76/100, Train metric: 1.3874
# Estimator 77/100, Train metric: 1.3802
# Estimator 78/100, Train metric: 1.3720
# Estimator 79/100, Train metric: 1.3580
# Estimator 80/100, Train metric: 1.3396
# Estimator 81/100, Train metric: 1.3337
# Estimator 82/100, Train metric: 1.3207
# Estimator 83/100, Train metric: 1.3072
# Estimator 84/100, Train metric: 1.2952
# Estimator 85/100, Train metric: 1.2880
# Estimator 86/100, Train metric: 1.2715
# Estimator 87/100, Train metric: 1.2634
# Estimator 88/100, Train metric: 1.2499
# Estimator 89/100, Train metric: 1.2308
# Estimator 90/100, Train metric: 1.2242
# Estimator 91/100, Train metric: 1.2170
# Estimator 92/100, Train metric: 1.2012
# Estimator 93/100, Train metric: 1.1954
# Estimator 94/100, Train metric: 1.1870
# Estimator 95/100, Train metric: 1.1795
# Estimator 96/100, Train metric: 1.1745
# Estimator 97/100, Train metric: 1.1668
# Estimator 98/100, Train metric: 1.1585
# Estimator 99/100, Train metric: 1.1527
# Best MSE for PGBM with WilcoxonPruner: 15.653099554500214 with params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_leaves': 27, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 3, 'max_bin': 64, 'distribution': 'studentt'}
# Best RMSE for PGBM with WilcoxonPruner: 3.956399822376426
# Correlation Coefficient for PGBM with WilcoxonPruner: 0.9660825513626198
#
# Best model on test data: GPBoost with NopPruner
# Test MSE: 10.07596275662353
# Test RMSE: 3.1742657035326345
# Correlation Coefficient: 0.9775981239828208
# Best Parameters: {'n_estimators': 400, 'learning_rate': 0.01, 'max_depth': -1, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 0.6, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 1.0, 'min_child_weight': 1e-05, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Pruner Used: NopPruner

# %%
best_scores_autosampler
# Out:
# {('Random Forest', 'MedianPruner'): {'best_score': 13.038158161806736,
#   'best_params': {'n_estimators': 500,
#    'criterion': 'friedman_mse',
#    'max_depth': 10,
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 1.0,
#    'max_leaf_nodes': 100,
#    'min_impurity_decrease': 0.0,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.001},
#   'test_mse': 13.038158161806736,
#   'test_rmse': 3.610838983090597,
#   'test_corr_coef': 0.9708197958491004,
#   'pruner': 'MedianPruner'},
#  ('Random Forest', 'NopPruner'): {'best_score': 13.033087634585193,
#   'best_params': {'n_estimators': 700,
#    'criterion': 'friedman_mse',
#    'max_depth': 30,
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 1.0,
#    'max_leaf_nodes': 200,
#    'min_impurity_decrease': 0.2,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.0},
#   'test_mse': 13.033087634585193,
#   'test_rmse': 3.6101367889022145,
#   'test_corr_coef': 0.9707049346475258,
#   'pruner': 'NopPruner'},
#  ('Random Forest', 'PatientPruner'): {'best_score': 14.454469361060458,
#   'best_params': {'n_estimators': 500,
#    'criterion': 'squared_error',
#    'max_depth': None,
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.5,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.001},
#   'test_mse': 14.454469361060458,
#   'test_rmse': 3.801903386602618,
#   'test_corr_coef': 0.968585284155265,
#   'pruner': 'PatientPruner'},
#  ('Random Forest', 'PercentilePruner'): {'best_score': 14.559932322520691,
#   'best_params': {'n_estimators': 200,
#    'criterion': 'friedman_mse',
#    'max_depth': None,
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 'log2',
#    'max_leaf_nodes': 100,
#    'min_impurity_decrease': 0.1,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.001},
#   'test_mse': 14.559932322520691,
#   'test_rmse': 3.815747937498059,
#   'test_corr_coef': 0.9685747522399442,
#   'pruner': 'PercentilePruner'},
#  ('Random Forest', 'SuccessiveHalvingPruner'): {'best_score': 13.2607369538564,
#   'best_params': {'n_estimators': 300,
#    'criterion': 'absolute_error',
#    'max_depth': 20,
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_features': 1.0,
#    'max_leaf_nodes': 200,
#    'min_impurity_decrease': 0.0,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.01},
#   'test_mse': 13.2607369538564,
#   'test_rmse': 3.641529480020229,
#   'test_corr_coef': 0.970496305061893,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('Random Forest', 'HyperbandPruner'): {'best_score': 13.036121626572406,
#   'best_params': {'n_estimators': 500,
#    'criterion': 'friedman_mse',
#    'max_depth': 20,
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_features': 1.0,
#    'max_leaf_nodes': 50,
#    'min_impurity_decrease': 0.1,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.01},
#   'test_mse': 13.036121626572406,
#   'test_rmse': 3.6105569690246413,
#   'test_corr_coef': 0.9708347466886161,
#   'pruner': 'HyperbandPruner'},
#  ('Random Forest', 'ThresholdPruner'): {'best_score': 13.396252070162644,
#   'best_params': {'n_estimators': 200,
#    'criterion': 'friedman_mse',
#    'max_depth': 10,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.01,
#    'max_features': 1.0,
#    'max_leaf_nodes': 50,
#    'min_impurity_decrease': 0.0,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.01},
#   'test_mse': 13.396252070162644,
#   'test_rmse': 3.660089079539273,
#   'test_corr_coef': 0.9702838235916544,
#   'pruner': 'ThresholdPruner'},
#  ('Random Forest', 'WilcoxonPruner'): {'best_score': 13.084370513807446,
#   'best_params': {'n_estimators': 500,
#    'criterion': 'squared_error',
#    'max_depth': 10,
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_features': 1.0,
#    'max_leaf_nodes': 50,
#    'min_impurity_decrease': 0.01,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.01},
#   'test_mse': 13.084370513807446,
#   'test_rmse': 3.617232438454494,
#   'test_corr_coef': 0.9707214904398097,
#   'pruner': 'WilcoxonPruner'},
#  ('Gradient Boosting', 'MedianPruner'): {'best_score': 12.153518081628253,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 100,
#    'subsample': 1.0,
#    'criterion': 'squared_error',
#    'min_samples_split': 5,
#    'min_samples_leaf': 5,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 5,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'log2',
#    'alpha': 0.1,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.01},
#   'test_mse': 12.153518081628253,
#   'test_rmse': 3.4861896221560085,
#   'test_corr_coef': 0.9724739175293039,
#   'pruner': 'MedianPruner'},
#  ('Gradient Boosting', 'NopPruner'): {'best_score': 10.28226837491786,
#   'best_params': {'loss': 'quantile',
#    'learning_rate': 0.2,
#    'n_estimators': 500,
#    'subsample': 0.9,
#    'criterion': 'squared_error',
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 5,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.001},
#   'test_mse': 10.28226837491786,
#   'test_rmse': 3.206597632213599,
#   'test_corr_coef': 0.9770583006149558,
#   'pruner': 'NopPruner'},
#  ('Gradient Boosting', 'PatientPruner'): {'best_score': 10.855147470416817,
#   'best_params': {'loss': 'absolute_error',
#    'learning_rate': 0.2,
#    'n_estimators': 300,
#    'subsample': 1.0,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 5,
#    'min_samples_leaf': 5,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'log2',
#    'alpha': 0.1,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.0},
#   'test_mse': 10.855147470416817,
#   'test_rmse': 3.2947150818267756,
#   'test_corr_coef': 0.9762052044989985,
#   'pruner': 'PatientPruner'},
#  ('Gradient Boosting', 'PercentilePruner'): {'best_score': 12.227422365513439,
#   'best_params': {'loss': 'absolute_error',
#    'learning_rate': 0.1,
#    'n_estimators': 500,
#    'subsample': 0.7,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'min_weight_fraction_leaf': 0.05,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.001,
#    'ccp_alpha': 0.0},
#   'test_mse': 12.227422365513439,
#   'test_rmse': 3.49677313612328,
#   'test_corr_coef': 0.9723282041700549,
#   'pruner': 'PercentilePruner'},
#  ('Gradient Boosting',
#   'SuccessiveHalvingPruner'): {'best_score': 12.073958499042682, 'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.01,
#    'n_estimators': 700,
#    'subsample': 0.7,
#    'criterion': 'squared_error',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 7,
#    'min_impurity_decrease': 0.01,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.1,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.001,
#    'ccp_alpha': 0.0}, 'test_mse': 12.073958499042682, 'test_rmse': 3.4747602074161437, 'test_corr_coef': 0.9729358954453631, 'pruner': 'SuccessiveHalvingPruner'},
#  ('Gradient Boosting', 'HyperbandPruner'): {'best_score': 11.607282355642464,
#   'best_params': {'loss': 'quantile',
#    'learning_rate': 0.1,
#    'n_estimators': 500,
#    'subsample': 0.7,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': None,
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 20,
#    'tol': 0.0001,
#    'ccp_alpha': 0.0},
#   'test_mse': 11.607282355642464,
#   'test_rmse': 3.4069461920673865,
#   'test_corr_coef': 0.9743534450205485,
#   'pruner': 'HyperbandPruner'},
#  ('Gradient Boosting', 'ThresholdPruner'): {'best_score': 12.097951550567178,
#   'best_params': {'loss': 'huber',
#    'learning_rate': 0.1,
#    'n_estimators': 500,
#    'subsample': 0.7,
#    'criterion': 'squared_error',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 7,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'log2',
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 10,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 20,
#    'tol': 0.001,
#    'ccp_alpha': 0.001},
#   'test_mse': 12.097951550567178,
#   'test_rmse': 3.478210969818705,
#   'test_corr_coef': 0.9742228783439729,
#   'pruner': 'ThresholdPruner'},
#  ('Gradient Boosting', 'WilcoxonPruner'): {'best_score': 12.044409277826345,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.2,
#    'n_estimators': 300,
#    'subsample': 0.7,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 5,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 20,
#    'tol': 0.0001,
#    'ccp_alpha': 0.001},
#   'test_mse': 12.044409277826345,
#   'test_rmse': 3.4705056227913453,
#   'test_corr_coef': 0.9753417406448451,
#   'pruner': 'WilcoxonPruner'},
#  ('XGBoost', 'MedianPruner'): {'best_score': 12.136811822631739,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.1,
#    'max_depth': 5,
#    'min_child_weight': 3,
#    'gamma': 0.1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 0.01,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 12.136811822631739,
#   'test_rmse': 3.4837927353147373,
#   'test_corr_coef': 0.9726184287908742,
#   'pruner': 'MedianPruner'},
#  ('XGBoost', 'NopPruner'): {'best_score': 12.723613138118791,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'min_child_weight': 1,
#    'gamma': 0.1,
#    'subsample': 0.5,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 10,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 12.723613138118791,
#   'test_rmse': 3.5670174008713205,
#   'test_corr_coef': 0.9710061366810492,
#   'pruner': 'NopPruner'},
#  ('XGBoost', 'PatientPruner'): {'best_score': 12.381260886155815,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'min_child_weight': 3,
#    'gamma': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 0,
#    'reg_lambda': 10,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 12.381260886155815,
#   'test_rmse': 3.5187015909502493,
#   'test_corr_coef': 0.9720178854417231,
#   'pruner': 'PatientPruner'},
#  ('XGBoost', 'PercentilePruner'): {'best_score': 12.450992778147029,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.05,
#    'max_depth': 7,
#    'min_child_weight': 3,
#    'gamma': 1,
#    'subsample': 0.8,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 0,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 12.450992778147029,
#   'test_rmse': 3.5285964317483276,
#   'test_corr_coef': 0.9718237007129169,
#   'pruner': 'PercentilePruner'},
#  ('XGBoost', 'SuccessiveHalvingPruner'): {'best_score': 13.223532782612663,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'min_child_weight': 3,
#    'gamma': 1,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 1,
#    'reg_lambda': 0.1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 13.223532782612663,
#   'test_rmse': 3.636417575391014,
#   'test_corr_coef': 0.9709108874636126,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('XGBoost', 'HyperbandPruner'): {'best_score': 13.255622907637404,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'gamma': 0.1,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 0.1,
#    'reg_lambda': 10,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 13.255622907637404,
#   'test_rmse': 3.640827228479457,
#   'test_corr_coef': 0.9701011518752937,
#   'pruner': 'HyperbandPruner'},
#  ('XGBoost', 'ThresholdPruner'): {'best_score': 13.262761390166697,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'max_depth': 7,
#    'min_child_weight': 3,
#    'gamma': 0.5,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 0.1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 13.262761390166697,
#   'test_rmse': 3.6418074345257048,
#   'test_corr_coef': 0.9706630473686867,
#   'pruner': 'ThresholdPruner'},
#  ('XGBoost', 'WilcoxonPruner'): {'best_score': 13.177546374116032,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.05,
#    'max_depth': 3,
#    'min_child_weight': 1,
#    'gamma': 0,
#    'subsample': 0.9,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 0.1,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 13.177546374116032,
#   'test_rmse': 3.6300890311555767,
#   'test_corr_coef': 0.9703781161586259,
#   'pruner': 'WilcoxonPruner'},
#  ('LightGBM', 'MedianPruner'): {'best_score': 10.546189666039878,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.01,
#    'num_leaves': 15,
#    'max_depth': 7,
#    'min_child_samples': 5,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 1,
#    'min_child_weight': 0.001,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 10.546189666039878,
#   'test_rmse': 3.2474897484118217,
#   'test_corr_coef': 0.9766190579472026,
#   'pruner': 'MedianPruner'},
#  ('LightGBM', 'NopPruner'): {'best_score': 10.66684160793602,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.05,
#    'num_leaves': 63,
#    'max_depth': 5,
#    'min_child_samples': 5,
#    'subsample': 1.0,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'min_child_weight': 0.01,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 10.66684160793602,
#   'test_rmse': 3.266013105903897,
#   'test_corr_coef': 0.9765091625074059,
#   'pruner': 'NopPruner'},
#  ('LightGBM', 'PatientPruner'): {'best_score': 10.185619350343222,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.01,
#    'num_leaves': 31,
#    'max_depth': 7,
#    'min_child_samples': 5,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.01,
#    'reg_lambda': 1,
#    'min_child_weight': 0.01,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 10.185619350343222,
#   'test_rmse': 3.1914917124039697,
#   'test_corr_coef': 0.9772662645941342,
#   'pruner': 'PatientPruner'},
#  ('LightGBM', 'PercentilePruner'): {'best_score': 10.537744732143034,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'num_leaves': 15,
#    'max_depth': 3,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 0.01,
#    'reg_lambda': 10,
#    'min_child_weight': 0.1,
#    'bagging_freq': 5,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 10.537744732143034,
#   'test_rmse': 3.2461892631427136,
#   'test_corr_coef': 0.9764198711478516,
#   'pruner': 'PercentilePruner'},
#  ('LightGBM', 'SuccessiveHalvingPruner'): {'best_score': 10.884310771235052,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'num_leaves': 31,
#    'max_depth': 5,
#    'min_child_samples': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'min_child_weight': 0.01,
#    'bagging_freq': 5,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 10.884310771235052,
#   'test_rmse': 3.2991378830286937,
#   'test_corr_coef': 0.9756862577674731,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('LightGBM', 'HyperbandPruner'): {'best_score': 10.381542181228612,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.05,
#    'num_leaves': 15,
#    'max_depth': 7,
#    'min_child_samples': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'min_child_weight': 0.001,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 10.381542181228612,
#   'test_rmse': 3.2220400651184664,
#   'test_corr_coef': 0.9766964186135217,
#   'pruner': 'HyperbandPruner'},
#  ('LightGBM', 'ThresholdPruner'): {'best_score': 11.469228256528801,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.01,
#    'num_leaves': 15,
#    'max_depth': 7,
#    'min_child_samples': 5,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.01,
#    'reg_lambda': 0,
#    'min_child_weight': 0.1,
#    'bagging_freq': 5,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 11.469228256528801,
#   'test_rmse': 3.386624906382282,
#   'test_corr_coef': 0.9743157085118995,
#   'pruner': 'ThresholdPruner'},
#  ('LightGBM', 'WilcoxonPruner'): {'best_score': 12.201127029952689,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.05,
#    'num_leaves': 15,
#    'max_depth': -1,
#    'min_child_samples': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 0,
#    'reg_lambda': 0.1,
#    'min_child_weight': 1e-05,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 12.201127029952689,
#   'test_rmse': 3.4930111694571906,
#   'test_corr_coef': 0.9730042368458391,
#   'pruner': 'WilcoxonPruner'},
#  ('GPBoost', 'MedianPruner'): {'best_score': 11.093470824663543,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.01,
#    'max_depth': 5,
#    'num_leaves': 63,
#    'min_child_samples': 5,
#    'subsample': 0.6,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 0,
#    'reg_lambda': 1.0,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 11.093470824663543,
#   'test_rmse': 3.330686239300175,
#   'test_corr_coef': 0.9754755695476137,
#   'pruner': 'MedianPruner'},
#  ('GPBoost', 'NopPruner'): {'best_score': 10.07596275662353,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.01,
#    'max_depth': -1,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 1.0,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 10.07596275662353,
#   'test_rmse': 3.1742657035326345,
#   'test_corr_coef': 0.9775981239828208,
#   'pruner': 'NopPruner'},
#  ('GPBoost', 'PatientPruner'): {'best_score': 10.316675056826002,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.01,
#    'max_depth': 7,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1.0,
#    'reg_lambda': 1.0,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 10.316675056826002,
#   'test_rmse': 3.211958134351381,
#   'test_corr_coef': 0.9769829603995179,
#   'pruner': 'PatientPruner'},
#  ('GPBoost', 'PercentilePruner'): {'best_score': 10.883635849337395,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.05,
#    'max_depth': 7,
#    'num_leaves': 15,
#    'min_child_samples': 10,
#    'subsample': 0.5,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 1.0,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 10.883635849337395,
#   'test_rmse': 3.2990355938269893,
#   'test_corr_coef': 0.975701562397981,
#   'pruner': 'PercentilePruner'},
#  ('GPBoost', 'SuccessiveHalvingPruner'): {'best_score': 10.222401709276937,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.01,
#    'max_depth': -1,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.5,
#    'reg_lambda': 0.5,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 10.222401709276937,
#   'test_rmse': 3.197249084647134,
#   'test_corr_coef': 0.9772831859837844,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('GPBoost', 'HyperbandPruner'): {'best_score': 11.282266380324323,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.05,
#    'max_depth': 5,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 1.0,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1.0,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 11.282266380324323,
#   'test_rmse': 3.3589085102640595,
#   'test_corr_coef': 0.9756924191454851,
#   'pruner': 'HyperbandPruner'},
#  ('GPBoost', 'ThresholdPruner'): {'best_score': 11.119245903100294,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'num_leaves': 15,
#    'min_child_samples': 1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 1.0,
#    'min_child_weight': 0.01,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 11.119245903100294,
#   'test_rmse': 3.3345533288733433,
#   'test_corr_coef': 0.9750722001144404,
#   'pruner': 'ThresholdPruner'},
#  ('GPBoost', 'WilcoxonPruner'): {'best_score': 11.28392806173546,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.01,
#    'max_depth': -1,
#    'num_leaves': 15,
#    'min_child_samples': 10,
#    'subsample': 1.0,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 0.5,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 11.28392806173546,
#   'test_rmse': 3.359155855529103,
#   'test_corr_coef': 0.9745089392104828,
#   'pruner': 'WilcoxonPruner'},
#  ('CatBoost', 'MedianPruner'): {'best_score': 12.272719969475748,
#   'best_params': {'iterations': 500,
#    'learning_rate': 0.05,
#    'depth': 8,
#    'l2_leaf_reg': 1,
#    'border_count': 32,
#    'min_data_in_leaf': 1,
#    'rsm': 0.6,
#    'bagging_temperature': 10,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 12.272719969475748,
#   'test_rmse': 3.503244206371538,
#   'test_corr_coef': 0.9726108411638906,
#   'pruner': 'MedianPruner'},
#  ('CatBoost', 'NopPruner'): {'best_score': 12.455296163968915,
#   'best_params': {'iterations': 500,
#    'learning_rate': 0.1,
#    'depth': 10,
#    'l2_leaf_reg': 9,
#    'border_count': 32,
#    'min_data_in_leaf': 10,
#    'rsm': 0.8,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 12.455296163968915,
#   'test_rmse': 3.5292061662601855,
#   'test_corr_coef': 0.9722824968535125,
#   'pruner': 'NopPruner'},
#  ('CatBoost', 'PatientPruner'): {'best_score': 12.412893712386444,
#   'best_params': {'iterations': 200,
#    'learning_rate': 0.05,
#    'depth': 6,
#    'l2_leaf_reg': 5,
#    'border_count': 32,
#    'min_data_in_leaf': 1,
#    'rsm': 0.6,
#    'bagging_temperature': 0,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 12.412893712386444,
#   'test_rmse': 3.5231936807939532,
#   'test_corr_coef': 0.9723833874013228,
#   'pruner': 'PatientPruner'},
#  ('CatBoost', 'PercentilePruner'): {'best_score': 11.855218020554956,
#   'best_params': {'iterations': 500,
#    'learning_rate': 0.03,
#    'depth': 8,
#    'l2_leaf_reg': 5,
#    'border_count': 32,
#    'min_data_in_leaf': 20,
#    'rsm': 0.8,
#    'bagging_temperature': 0,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 11.855218020554956,
#   'test_rmse': 3.443140720411374,
#   'test_corr_coef': 0.9736540447216337,
#   'pruner': 'PercentilePruner'},
#  ('CatBoost', 'SuccessiveHalvingPruner'): {'best_score': 10.919798187835573,
#   'best_params': {'iterations': 200,
#    'learning_rate': 0.05,
#    'depth': 10,
#    'l2_leaf_reg': 1,
#    'border_count': 32,
#    'min_data_in_leaf': 1,
#    'rsm': 1.0,
#    'bagging_temperature': 10,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 10.919798187835573,
#   'test_rmse': 3.3045117926609935,
#   'test_corr_coef': 0.9763196998303095,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('CatBoost', 'HyperbandPruner'): {'best_score': 11.942747714870922,
#   'best_params': {'iterations': 500,
#    'learning_rate': 0.05,
#    'depth': 10,
#    'l2_leaf_reg': 7,
#    'border_count': 128,
#    'min_data_in_leaf': 10,
#    'rsm': 0.6,
#    'bagging_temperature': 0,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 11.942747714870922,
#   'test_rmse': 3.4558280794725484,
#   'test_corr_coef': 0.9733039847347529,
#   'pruner': 'HyperbandPruner'},
#  ('CatBoost', 'ThresholdPruner'): {'best_score': 11.08404516153846,
#   'best_params': {'iterations': 500,
#    'learning_rate': 0.05,
#    'depth': 10,
#    'l2_leaf_reg': 1,
#    'border_count': 32,
#    'min_data_in_leaf': 10,
#    'rsm': 1.0,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 11.08404516153846,
#   'test_rmse': 3.3292709654725403,
#   'test_corr_coef': 0.9759763178694743,
#   'pruner': 'ThresholdPruner'},
#  ('CatBoost', 'WilcoxonPruner'): {'best_score': 12.260759760587039,
#   'best_params': {'iterations': 500,
#    'learning_rate': 0.03,
#    'depth': 8,
#    'l2_leaf_reg': 7,
#    'border_count': 32,
#    'min_data_in_leaf': 10,
#    'rsm': 0.8,
#    'bagging_temperature': 0,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 12.260759760587039,
#   'test_rmse': 3.5015367712744414,
#   'test_corr_coef': 0.9729419180582299,
#   'pruner': 'WilcoxonPruner'},
#  ('NGBoost', 'MedianPruner'): {'best_score': 12.988271035439867,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.03,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 12.988271035439867,
#   'test_rmse': 3.603924393690837,
#   'test_corr_coef': 0.9710197025716992,
#   'pruner': 'MedianPruner'},
#  ('NGBoost', 'NopPruner'): {'best_score': 13.335517008968388,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.03,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 13.335517008968388,
#   'test_rmse': 3.651782716560281,
#   'test_corr_coef': 0.9698560099630124,
#   'pruner': 'NopPruner'},
#  ('NGBoost', 'PatientPruner'): {'best_score': 14.597899752729637,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.05,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 1.0,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 14.597899752729637,
#   'test_rmse': 3.8207197951079372,
#   'test_corr_coef': 0.9669288311765937,
#   'pruner': 'PatientPruner'},
#  ('NGBoost', 'PercentilePruner'): {'best_score': 12.83715509365134,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.03,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 12.83715509365134,
#   'test_rmse': 3.582897583472257,
#   'test_corr_coef': 0.9709457051145279,
#   'pruner': 'PercentilePruner'},
#  ('NGBoost', 'SuccessiveHalvingPruner'): {'best_score': 12.452832352634385,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.03,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 12.452832352634385,
#   'test_rmse': 3.528857088723541,
#   'test_corr_coef': 0.9716987675973743,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('NGBoost', 'HyperbandPruner'): {'best_score': 13.098905683055307,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.03,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 13.098905683055307,
#   'test_rmse': 3.619241036882637,
#   'test_corr_coef': 0.9703003692092006,
#   'pruner': 'HyperbandPruner'},
#  ('NGBoost', 'ThresholdPruner'): {'best_score': 12.035903691269185,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.03,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 12.035903691269185,
#   'test_rmse': 3.4692799960898495,
#   'test_corr_coef': 0.9728649028395556,
#   'pruner': 'ThresholdPruner'},
#  ('NGBoost', 'WilcoxonPruner'): {'best_score': 12.667599761291468,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.03,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 12.667599761291468,
#   'test_rmse': 3.559157170074324,
#   'test_corr_coef': 0.9715007054198,
#   'pruner': 'WilcoxonPruner'},
#  ('HistGradientBoosting', 'MedianPruner'): {'best_score': 10.471840797020173,
#   'best_params': {'learning_rate': 0.05,
#    'max_iter': 400,
#    'max_depth': None,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': None,
#    'l2_regularization': 1.0,
#    'max_bins': 64,
#    'early_stopping': True,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 10.471840797020173,
#   'test_rmse': 3.236022372762613,
#   'test_corr_coef': 0.9766586844671373,
#   'pruner': 'MedianPruner'},
#  ('HistGradientBoosting', 'NopPruner'): {'best_score': 12.073827638061124,
#   'best_params': {'learning_rate': 0.01,
#    'max_iter': 400,
#    'max_depth': None,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 1.0,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 12.073827638061124,
#   'test_rmse': 3.4747413771475313,
#   'test_corr_coef': 0.9727068556280255,
#   'pruner': 'NopPruner'},
#  ('HistGradientBoosting', 'PatientPruner'): {'best_score': 10.292353900564587,
#   'best_params': {'learning_rate': 0.05,
#    'max_iter': 500,
#    'max_depth': None,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': None,
#    'l2_regularization': 0.5,
#    'max_bins': 64,
#    'early_stopping': True,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 10.292353900564587,
#   'test_rmse': 3.20816986778515,
#   'test_corr_coef': 0.9771500387696429,
#   'pruner': 'PatientPruner'},
#  ('HistGradientBoosting',
#   'PercentilePruner'): {'best_score': 10.392964120061412, 'best_params': {'learning_rate': 0.05,
#    'max_iter': 300,
#    'max_depth': 5,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.0,
#    'max_bins': 64,
#    'early_stopping': True,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 10.392964120061412, 'test_rmse': 3.223812047880802, 'test_corr_coef': 0.9769099995945186, 'pruner': 'PercentilePruner'},
#  ('HistGradientBoosting',
#   'SuccessiveHalvingPruner'): {'best_score': 12.738329871653146, 'best_params': {'learning_rate': 0.01,
#    'max_iter': 300,
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 1.0,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 12.738329871653146, 'test_rmse': 3.5690796953350796, 'test_corr_coef': 0.9729987904189179, 'pruner': 'SuccessiveHalvingPruner'},
#  ('HistGradientBoosting',
#   'HyperbandPruner'): {'best_score': 12.738329871653146, 'best_params': {'learning_rate': 0.01,
#    'max_iter': 300,
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 1.0,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 12.738329871653146, 'test_rmse': 3.5690796953350796, 'test_corr_coef': 0.9729987904189179, 'pruner': 'HyperbandPruner'},
#  ('HistGradientBoosting',
#   'ThresholdPruner'): {'best_score': 10.292353900564587, 'best_params': {'learning_rate': 0.05,
#    'max_iter': 300,
#    'max_depth': None,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.5,
#    'max_bins': 64,
#    'early_stopping': True,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 10.292353900564587, 'test_rmse': 3.20816986778515, 'test_corr_coef': 0.9771500387696429, 'pruner': 'ThresholdPruner'},
#  ('HistGradientBoosting', 'WilcoxonPruner'): {'best_score': 10.292353900564587,
#   'best_params': {'learning_rate': 0.05,
#    'max_iter': 200,
#    'max_depth': None,
#    'min_samples_leaf': 10,
#    'max_leaf_nodes': 63,
#    'l2_regularization': 0.5,
#    'max_bins': 64,
#    'early_stopping': True,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 10.292353900564587,
#   'test_rmse': 3.20816986778515,
#   'test_corr_coef': 0.9771500387696429,
#   'pruner': 'WilcoxonPruner'},
#  ('PGBM', 'MedianPruner'): {'best_score': 15.171240778431299,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.1,
#    'max_leaves': 63,
#    'min_split_gain': 0.0,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 5,
#    'max_bin': 64,
#    'distribution': 'studentt'},
#   'test_mse': 15.171240778431299,
#   'test_rmse': 3.8950276993150252,
#   'test_corr_coef': 0.9673690326713885,
#   'pruner': 'MedianPruner'},
#  ('PGBM', 'NopPruner'): {'best_score': 15.623112163352925,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.1,
#    'max_leaves': 31,
#    'min_split_gain': 0.5,
#    'reg_lambda': 10.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 5,
#    'max_bin': 64,
#    'distribution': 'studentt'},
#   'test_mse': 15.623112163352925,
#   'test_rmse': 3.952608273450953,
#   'test_corr_coef': 0.9666119657338578,
#   'pruner': 'NopPruner'},
#  ('PGBM', 'PatientPruner'): {'best_score': 14.837016974346849,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.1,
#    'max_leaves': 37,
#    'min_split_gain': 0.1,
#    'reg_lambda': 10.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 14.837016974346849,
#   'test_rmse': 3.8518848599545197,
#   'test_corr_coef': 0.9688540495546439,
#   'pruner': 'PatientPruner'},
#  ('PGBM', 'PercentilePruner'): {'best_score': 14.410246947538797,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.05,
#    'max_leaves': 48,
#    'min_split_gain': 0.5,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.1,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 14.410246947538797,
#   'test_rmse': 3.796083105984219,
#   'test_corr_coef': 0.9705438016051792,
#   'pruner': 'PercentilePruner'},
#  ('PGBM', 'SuccessiveHalvingPruner'): {'best_score': 16.586132297171112,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.05,
#    'max_leaves': 17,
#    'min_split_gain': 0.0,
#    'reg_lambda': 0.1,
#    'feature_fraction': 1.0,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.0,
#    'min_data_in_leaf': 5,
#    'max_bin': 256,
#    'distribution': 'normal'},
#   'test_mse': 16.586132297171112,
#   'test_rmse': 4.072607555015719,
#   'test_corr_coef': 0.9637100520914976,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('PGBM', 'HyperbandPruner'): {'best_score': 14.46691883448201,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.15,
#    'max_leaves': 31,
#    'min_split_gain': 0.0,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.1,
#    'min_data_in_leaf': 3,
#    'max_bin': 256,
#    'distribution': 'normal'},
#   'test_mse': 14.46691883448201,
#   'test_rmse': 3.803540302728763,
#   'test_corr_coef': 0.9693321886495186,
#   'pruner': 'HyperbandPruner'},
#  ('PGBM', 'ThresholdPruner'): {'best_score': 15.893417514351563,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.05,
#    'max_leaves': 48,
#    'min_split_gain': 1.0,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.0,
#    'min_data_in_leaf': 5,
#    'max_bin': 64,
#    'distribution': 'studentt'},
#   'test_mse': 15.893417514351563,
#   'test_rmse': 3.9866549279253607,
#   'test_corr_coef': 0.9679821523563314,
#   'pruner': 'ThresholdPruner'},
#  ('PGBM', 'WilcoxonPruner'): {'best_score': 15.653099554500214,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.1,
#    'max_leaves': 27,
#    'min_split_gain': 0.0,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.0,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'studentt'},
#   'test_mse': 15.653099554500214,
#   'test_rmse': 3.956399822376426,
#   'test_corr_coef': 0.9660825513626198,
#   'pruner': 'WilcoxonPruner'}}

# %% [markdown]
# # **Best Model Analysis**

# %%
def get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, file_path):
    # Convert input data to NumPy arrays
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    # Mapping for model creation based on dictionary keys
    model_mapping = {
        'Random Forest': RandomForestRegressor,
        'Gradient Boosting': GradientBoostingRegressor,
        'XGBoost': XGBRegressor,
        'LightGBM': LGBMRegressor,
        'CatBoost': CatBoostRegressor,
        'GPBoost': GPBoostRegressor,
        'NGBoost': NGBRegressor,
        'HistGradientBoosting': HistGradientBoostingRegressor,
        'PGBM': PGBM  # PGBM is handled separately
    }

    # Dictionary to store the best model for each type
    best_models = {}

    # Iterate over the dictionary to find the best pruner for each model type
    for (model_name, pruner), params in best_scores_autosampler.items():
        current_score = params.get('test_mse', np.inf)
        if model_name not in best_models or current_score < best_models[model_name]['score']:
            best_models[model_name] = {
                'score': current_score,
                'params': params['best_params'],
                'pruner': pruner
            }

    # Prepare a DataFrame to store predictions
    df = pd.read_csv(file_path)

    # Iterate over the best models to train and predict
    for model_name, model_info in best_models.items():
        best_params = model_info['params']
        model_class = model_mapping.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        # Handle specific parameters or settings for model if needed
        if model_name == 'CatBoost':
            best_params.pop('verbose', None)  # Remove 'verbose' for CatBoost

        # Create an instance of the best model with the best parameters
        if model_name == 'PGBM':
            model = model_class()
            model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params)
            predictions = model.predict(X_test)
        else:
            model = model_class(**best_params)
            model.fit(X_train, y_train)
            predictions = model.predict(X_test)

        # Add predictions to the DataFrame
        df[f'{model_name} Predictions'] = predictions

        # Plot actual vs. predicted
        plt.figure(figsize=(10, 6))
        plt.scatter(y_test, predictions, alpha=0.6)
        plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', color='red', lw=2)
        plt.xlabel("Actual")
        plt.ylabel("Predicted")
        plt.title(f"Actual vs. Predicted Values ({model_name})")
        plt.grid(True)
        plt.tight_layout()

        # Save the plot temporarily
        plot_path = f'temp_plot_{model_name}.png'
        plt.savefig(plot_path)
        plt.close()

    # Save predictions and plots to Excel
    with pd.ExcelWriter(file_path.replace('.csv', '_results.xlsx'), engine='xlsxwriter') as writer:
        # Write data to Excel
        df.to_excel(writer, sheet_name='Data', index=False)

        # Get the xlsxwriter objects
        workbook = writer.book

        # Insert each plot into a separate worksheet
        for model_name in best_models.keys():
            # Shorten the worksheet name to fit within Excel's 31 character limit
            short_model_name = ''.join([word[0] for word in model_name.split()])  # e.g., 'RF' for 'Random Forest'
            sheet_name = f'{short_model_name}_Plot'

            worksheet = workbook.add_worksheet(sheet_name)
            writer.sheets[sheet_name] = worksheet
            plot_path = f'temp_plot_{model_name}.png'
            worksheet.insert_image('A1', plot_path)

    # Clean up temporary plot files
    for model_name in best_models.keys():
        os.remove(f'temp_plot_{model_name}.png')

    return df, best_models

# Call the function
df, best_models = get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, "./drive/MyDrive/NOISE/test.csv")
# Out:
# 0:	learn: 13.6460314	total: 2.35ms	remaining: 469ms
# 1:	learn: 13.1156430	total: 4.46ms	remaining: 442ms
# 2:	learn: 12.6102176	total: 6.05ms	remaining: 397ms
# 3:	learn: 12.1210888	total: 6.67ms	remaining: 327ms
# 4:	learn: 11.6414665	total: 8.25ms	remaining: 322ms
# 5:	learn: 11.1842282	total: 9.65ms	remaining: 312ms
# 6:	learn: 10.7323871	total: 10.1ms	remaining: 280ms
# 7:	learn: 10.3211576	total: 11.6ms	remaining: 279ms
# 8:	learn: 9.9740786	total: 13.1ms	remaining: 278ms
# 9:	learn: 9.6025380	total: 14.6ms	remaining: 277ms
# 10:	learn: 9.2401264	total: 16ms	remaining: 274ms
# 11:	learn: 8.8883700	total: 17.4ms	remaining: 273ms
# 12:	learn: 8.5761083	total: 18.9ms	remaining: 272ms
# 13:	learn: 8.2740709	total: 20.3ms	remaining: 270ms
# 14:	learn: 7.9977575	total: 21.7ms	remaining: 268ms
# 15:	learn: 7.7042285	total: 23.1ms	remaining: 265ms
# 16:	learn: 7.4603375	total: 24.5ms	remaining: 263ms
# 17:	learn: 7.2010851	total: 26ms	remaining: 263ms
# 18:	learn: 6.9772135	total: 27.5ms	remaining: 262ms
# 19:	learn: 6.7511451	total: 28.9ms	remaining: 260ms
# 20:	learn: 6.5127842	total: 30.3ms	remaining: 258ms
# 21:	learn: 6.3023864	total: 31.7ms	remaining: 256ms
# 22:	learn: 6.1098295	total: 32.6ms	remaining: 251ms
# 23:	learn: 5.9196935	total: 33.3ms	remaining: 244ms
# 24:	learn: 5.7533625	total: 34.9ms	remaining: 244ms
# 25:	learn: 5.5626675	total: 35.7ms	remaining: 239ms
# 26:	learn: 5.3934072	total: 37.4ms	remaining: 240ms
# 27:	learn: 5.2312180	total: 38.2ms	remaining: 235ms
# 28:	learn: 5.1200328	total: 38.3ms	remaining: 226ms
# 29:	learn: 4.9529153	total: 40ms	remaining: 227ms
# 30:	learn: 4.7966648	total: 41.5ms	remaining: 226ms
# 31:	learn: 4.6441486	total: 42.9ms	remaining: 225ms
# 32:	learn: 4.5083975	total: 44.6ms	remaining: 226ms
# 33:	learn: 4.3959859	total: 46.2ms	remaining: 226ms
# 34:	learn: 4.2588248	total: 47.8ms	remaining: 225ms
# 35:	learn: 4.1610889	total: 49.3ms	remaining: 225ms
# 36:	learn: 4.0701217	total: 50.8ms	remaining: 224ms
# 37:	learn: 3.9739726	total: 51.7ms	remaining: 220ms
# 38:	learn: 3.8566342	total: 53.1ms	remaining: 219ms
# 39:	learn: 3.7754942	total: 53.4ms	remaining: 214ms
# 40:	learn: 3.6935194	total: 54.9ms	remaining: 213ms
# 41:	learn: 3.6219602	total: 55.2ms	remaining: 208ms
# 42:	learn: 3.5327523	total: 56.5ms	remaining: 206ms
# 43:	learn: 3.4719886	total: 58ms	remaining: 206ms
# 44:	learn: 3.4178376	total: 58.6ms	remaining: 202ms
# 45:	learn: 3.3516633	total: 60ms	remaining: 201ms
# 46:	learn: 3.2874943	total: 61.4ms	remaining: 200ms
# 47:	learn: 3.2406449	total: 61.5ms	remaining: 195ms
# 48:	learn: 3.1556086	total: 62.9ms	remaining: 194ms
# 49:	learn: 3.0982220	total: 64.4ms	remaining: 193ms
# 50:	learn: 3.0206454	total: 65.8ms	remaining: 192ms
# 51:	learn: 2.9621009	total: 67.2ms	remaining: 191ms
# 52:	learn: 2.8904433	total: 68.6ms	remaining: 190ms
# 53:	learn: 2.8440632	total: 68.8ms	remaining: 186ms
# 54:	learn: 2.7870877	total: 70.2ms	remaining: 185ms
# 55:	learn: 2.7420465	total: 71ms	remaining: 183ms
# 56:	learn: 2.6955591	total: 72.3ms	remaining: 181ms
# 57:	learn: 2.6434271	total: 73.7ms	remaining: 180ms
# 58:	learn: 2.6018339	total: 75.1ms	remaining: 179ms
# 59:	learn: 2.5745202	total: 75.5ms	remaining: 176ms
# 60:	learn: 2.5312376	total: 76.8ms	remaining: 175ms
# 61:	learn: 2.4748437	total: 78.2ms	remaining: 174ms
# 62:	learn: 2.4317576	total: 79.6ms	remaining: 173ms
# 63:	learn: 2.3822592	total: 81.1ms	remaining: 172ms
# 64:	learn: 2.3454744	total: 82.6ms	remaining: 172ms
# 65:	learn: 2.3067490	total: 84.1ms	remaining: 171ms
# 66:	learn: 2.2783889	total: 85.6ms	remaining: 170ms
# 67:	learn: 2.2506748	total: 87ms	remaining: 169ms
# 68:	learn: 2.2148172	total: 88.5ms	remaining: 168ms
# 69:	learn: 2.1814215	total: 89.3ms	remaining: 166ms
# 70:	learn: 2.1620683	total: 90.7ms	remaining: 165ms
# 71:	learn: 2.1383024	total: 92ms	remaining: 164ms
# 72:	learn: 2.1083426	total: 93.4ms	remaining: 163ms
# 73:	learn: 2.0967326	total: 93.5ms	remaining: 159ms
# 74:	learn: 2.0731257	total: 94.9ms	remaining: 158ms
# 75:	learn: 2.0597693	total: 96.3ms	remaining: 157ms
# 76:	learn: 2.0353036	total: 97.7ms	remaining: 156ms
# 77:	learn: 2.0125192	total: 99.3ms	remaining: 155ms
# 78:	learn: 1.9839001	total: 101ms	remaining: 154ms
# 79:	learn: 1.9530115	total: 102ms	remaining: 153ms
# 80:	learn: 1.9203487	total: 104ms	remaining: 152ms
# 81:	learn: 1.8909647	total: 105ms	remaining: 151ms
# 82:	learn: 1.8668520	total: 107ms	remaining: 150ms
# 83:	learn: 1.8354438	total: 108ms	remaining: 149ms
# 84:	learn: 1.8164996	total: 109ms	remaining: 148ms
# 85:	learn: 1.7856815	total: 111ms	remaining: 147ms
# 86:	learn: 1.7639758	total: 112ms	remaining: 146ms
# 87:	learn: 1.7481861	total: 114ms	remaining: 145ms
# 88:	learn: 1.7263027	total: 115ms	remaining: 144ms
# 89:	learn: 1.6961594	total: 117ms	remaining: 143ms
# 90:	learn: 1.6721306	total: 118ms	remaining: 141ms
# 91:	learn: 1.6500036	total: 120ms	remaining: 141ms
# 92:	learn: 1.6252223	total: 121ms	remaining: 140ms
# 93:	learn: 1.6021054	total: 123ms	remaining: 139ms
# 94:	learn: 1.5786255	total: 124ms	remaining: 138ms
# 95:	learn: 1.5528852	total: 126ms	remaining: 136ms
# 96:	learn: 1.5324565	total: 127ms	remaining: 135ms
# 97:	learn: 1.5200099	total: 129ms	remaining: 134ms
# 98:	learn: 1.4994908	total: 130ms	remaining: 133ms
# 99:	learn: 1.4775938	total: 132ms	remaining: 132ms
# 100:	learn: 1.4564895	total: 133ms	remaining: 130ms
# 101:	learn: 1.4393100	total: 135ms	remaining: 130ms
# 102:	learn: 1.4170668	total: 136ms	remaining: 129ms
# 103:	learn: 1.4073605	total: 138ms	remaining: 127ms
# 104:	learn: 1.3909426	total: 139ms	remaining: 126ms
# 105:	learn: 1.3819244	total: 141ms	remaining: 125ms
# 106:	learn: 1.3613512	total: 142ms	remaining: 124ms
# 107:	learn: 1.3446528	total: 144ms	remaining: 123ms
# 108:	learn: 1.3345380	total: 145ms	remaining: 121ms
# 109:	learn: 1.3264187	total: 147ms	remaining: 120ms
# 110:	learn: 1.3118331	total: 148ms	remaining: 119ms
# 111:	learn: 1.2905354	total: 150ms	remaining: 118ms
# 112:	learn: 1.2790294	total: 151ms	remaining: 117ms
# 113:	learn: 1.2695529	total: 153ms	remaining: 115ms
# 114:	learn: 1.2613239	total: 154ms	remaining: 114ms
# 115:	learn: 1.2511975	total: 156ms	remaining: 113ms
# 116:	learn: 1.2435575	total: 157ms	remaining: 111ms
# 117:	learn: 1.2270193	total: 159ms	remaining: 110ms
# 118:	learn: 1.2073204	total: 160ms	remaining: 109ms
# 119:	learn: 1.1953830	total: 162ms	remaining: 108ms
# 120:	learn: 1.1844009	total: 163ms	remaining: 106ms
# 121:	learn: 1.1662849	total: 164ms	remaining: 105ms
# 122:	learn: 1.1576927	total: 166ms	remaining: 104ms
# 123:	learn: 1.1489689	total: 167ms	remaining: 103ms
# 124:	learn: 1.1438640	total: 169ms	remaining: 101ms
# 125:	learn: 1.1263104	total: 170ms	remaining: 100ms
# 126:	learn: 1.1207278	total: 172ms	remaining: 98.8ms
# 127:	learn: 1.1086842	total: 173ms	remaining: 97.5ms
# 128:	learn: 1.0908027	total: 175ms	remaining: 96.2ms
# 129:	learn: 1.0824522	total: 176ms	remaining: 94.9ms
# 130:	learn: 1.0737390	total: 178ms	remaining: 93.7ms
# 131:	learn: 1.0620216	total: 179ms	remaining: 92.4ms
# 132:	learn: 1.0538906	total: 181ms	remaining: 91.1ms
# 133:	learn: 1.0470825	total: 182ms	remaining: 89.7ms
# 134:	learn: 1.0396622	total: 184ms	remaining: 88.4ms
# 135:	learn: 1.0286353	total: 185ms	remaining: 87ms
# 136:	learn: 1.0206639	total: 186ms	remaining: 85.7ms
# 137:	learn: 1.0137299	total: 188ms	remaining: 84.4ms
# 138:	learn: 1.0008257	total: 189ms	remaining: 83.1ms
# 139:	learn: 0.9871698	total: 191ms	remaining: 81.8ms
# 140:	learn: 0.9804481	total: 192ms	remaining: 80.4ms
# 141:	learn: 0.9704254	total: 196ms	remaining: 80.1ms
# 142:	learn: 0.9642354	total: 199ms	remaining: 79.2ms
# 143:	learn: 0.9582481	total: 200ms	remaining: 77.9ms
# 144:	learn: 0.9450501	total: 202ms	remaining: 76.6ms
# 145:	learn: 0.9331867	total: 203ms	remaining: 75.2ms
# 146:	learn: 0.9269271	total: 205ms	remaining: 73.9ms
# 147:	learn: 0.9104055	total: 206ms	remaining: 72.5ms
# 148:	learn: 0.8941248	total: 208ms	remaining: 71.2ms
# 149:	learn: 0.8885222	total: 209ms	remaining: 69.8ms
# 150:	learn: 0.8749603	total: 211ms	remaining: 68.4ms
# 151:	learn: 0.8685097	total: 212ms	remaining: 67ms
# 152:	learn: 0.8623154	total: 214ms	remaining: 65.6ms
# 153:	learn: 0.8534944	total: 215ms	remaining: 64.3ms
# 154:	learn: 0.8379400	total: 217ms	remaining: 62.9ms
# 155:	learn: 0.8258315	total: 218ms	remaining: 61.5ms
# 156:	learn: 0.8139527	total: 219ms	remaining: 60.1ms
# 157:	learn: 0.8005418	total: 221ms	remaining: 58.7ms
# 158:	learn: 0.7926209	total: 222ms	remaining: 57.3ms
# 159:	learn: 0.7858231	total: 224ms	remaining: 55.9ms
# 160:	learn: 0.7804552	total: 225ms	remaining: 54.5ms
# 161:	learn: 0.7749268	total: 226ms	remaining: 53.1ms
# 162:	learn: 0.7646567	total: 228ms	remaining: 51.7ms
# 163:	learn: 0.7587319	total: 229ms	remaining: 50.4ms
# 164:	learn: 0.7459306	total: 231ms	remaining: 49ms
# 165:	learn: 0.7410604	total: 232ms	remaining: 47.6ms
# 166:	learn: 0.7359467	total: 234ms	remaining: 46.2ms
# 167:	learn: 0.7232259	total: 235ms	remaining: 44.8ms
# 168:	learn: 0.7182242	total: 237ms	remaining: 43.4ms
# 169:	learn: 0.7094075	total: 238ms	remaining: 42.1ms
# 170:	learn: 0.7004463	total: 240ms	remaining: 40.7ms
# 171:	learn: 0.6960579	total: 241ms	remaining: 39.3ms
# 172:	learn: 0.6907828	total: 243ms	remaining: 37.9ms
# 173:	learn: 0.6862883	total: 244ms	remaining: 36.5ms
# 174:	learn: 0.6820272	total: 246ms	remaining: 35.1ms
# 175:	learn: 0.6732279	total: 247ms	remaining: 33.7ms
# 176:	learn: 0.6684559	total: 248ms	remaining: 32.3ms
# 177:	learn: 0.6585551	total: 250ms	remaining: 30.9ms
# 178:	learn: 0.6516359	total: 251ms	remaining: 29.5ms
# 179:	learn: 0.6433039	total: 253ms	remaining: 28.1ms
# 180:	learn: 0.6347405	total: 255ms	remaining: 26.7ms
# 181:	learn: 0.6256148	total: 256ms	remaining: 25.3ms
# 182:	learn: 0.6177829	total: 258ms	remaining: 23.9ms
# 183:	learn: 0.6131190	total: 259ms	remaining: 22.5ms
# 184:	learn: 0.6091738	total: 261ms	remaining: 21.1ms
# 185:	learn: 0.6052229	total: 262ms	remaining: 19.7ms
# 186:	learn: 0.6017539	total: 263ms	remaining: 18.3ms
# 187:	learn: 0.5934614	total: 265ms	remaining: 16.9ms
# 188:	learn: 0.5848668	total: 266ms	remaining: 15.5ms
# 189:	learn: 0.5806333	total: 268ms	remaining: 14.1ms
# 190:	learn: 0.5739420	total: 269ms	remaining: 12.7ms
# 191:	learn: 0.5713813	total: 270ms	remaining: 11.3ms
# 192:	learn: 0.5679859	total: 272ms	remaining: 9.85ms
# 193:	learn: 0.5607543	total: 273ms	remaining: 8.45ms
# 194:	learn: 0.5573446	total: 275ms	remaining: 7.04ms
# 195:	learn: 0.5483025	total: 276ms	remaining: 5.64ms
# 196:	learn: 0.5417148	total: 278ms	remaining: 4.23ms
# 197:	learn: 0.5341555	total: 279ms	remaining: 2.82ms
# 198:	learn: 0.5311638	total: 280ms	remaining: 1.41ms
# 199:	learn: 0.5276216	total: 282ms	remaining: 0us
# Training on CPU
# Estimator 0/100, Train metric: 13.6600
# Estimator 1/100, Train metric: 13.1362
# Estimator 2/100, Train metric: 12.6630
# Estimator 3/100, Train metric: 12.2133
# Estimator 4/100, Train metric: 11.7673
# Estimator 5/100, Train metric: 11.3432
# Estimator 6/100, Train metric: 10.9165
# Estimator 7/100, Train metric: 10.5190
# Estimator 8/100, Train metric: 10.1357
# Estimator 9/100, Train metric: 9.7800
# Estimator 10/100, Train metric: 9.4528
# Estimator 11/100, Train metric: 9.1457
# Estimator 12/100, Train metric: 8.8370
# Estimator 13/100, Train metric: 8.5522
# Estimator 14/100, Train metric: 8.2619
# Estimator 15/100, Train metric: 8.0023
# Estimator 16/100, Train metric: 7.7424
# Estimator 17/100, Train metric: 7.4952
# Estimator 18/100, Train metric: 7.2477
# Estimator 19/100, Train metric: 7.0131
# Estimator 20/100, Train metric: 6.8115
# Estimator 21/100, Train metric: 6.6034
# Estimator 22/100, Train metric: 6.4033
# Estimator 23/100, Train metric: 6.2098
# Estimator 24/100, Train metric: 6.0252
# Estimator 25/100, Train metric: 5.8461
# Estimator 26/100, Train metric: 5.6753
# Estimator 27/100, Train metric: 5.5092
# Estimator 28/100, Train metric: 5.3606
# Estimator 29/100, Train metric: 5.2065
# Estimator 30/100, Train metric: 5.0708
# Estimator 31/100, Train metric: 4.9325
# Estimator 32/100, Train metric: 4.8146
# Estimator 33/100, Train metric: 4.6878
# Estimator 34/100, Train metric: 4.5715
# Estimator 35/100, Train metric: 4.4542
# Estimator 36/100, Train metric: 4.3519
# Estimator 37/100, Train metric: 4.2431
# Estimator 38/100, Train metric: 4.1367
# Estimator 39/100, Train metric: 4.0329
# Estimator 40/100, Train metric: 3.9478
# Estimator 41/100, Train metric: 3.8592
# Estimator 42/100, Train metric: 3.7725
# Estimator 43/100, Train metric: 3.6943
# Estimator 44/100, Train metric: 3.6226
# Estimator 45/100, Train metric: 3.5397
# Estimator 46/100, Train metric: 3.4578
# Estimator 47/100, Train metric: 3.3835
# Estimator 48/100, Train metric: 3.3148
# Estimator 49/100, Train metric: 3.2526
# Estimator 50/100, Train metric: 3.1911
# Estimator 51/100, Train metric: 3.1300
# Estimator 52/100, Train metric: 3.0715
# Estimator 53/100, Train metric: 3.0158
# Estimator 54/100, Train metric: 2.9703
# Estimator 55/100, Train metric: 2.9162
# Estimator 56/100, Train metric: 2.8678
# Estimator 57/100, Train metric: 2.8080
# Estimator 58/100, Train metric: 2.7549
# Estimator 59/100, Train metric: 2.7060
# Estimator 60/100, Train metric: 2.6619
# Estimator 61/100, Train metric: 2.6151
# Estimator 62/100, Train metric: 2.5744
# Estimator 63/100, Train metric: 2.5327
# Estimator 64/100, Train metric: 2.4944
# Estimator 65/100, Train metric: 2.4533
# Estimator 66/100, Train metric: 2.4150
# Estimator 67/100, Train metric: 2.3764
# Estimator 68/100, Train metric: 2.3419
# Estimator 69/100, Train metric: 2.3060
# Estimator 70/100, Train metric: 2.2705
# Estimator 71/100, Train metric: 2.2437
# Estimator 72/100, Train metric: 2.2099
# Estimator 73/100, Train metric: 2.1829
# Estimator 74/100, Train metric: 2.1534
# Estimator 75/100, Train metric: 2.1198
# Estimator 76/100, Train metric: 2.0913
# Estimator 77/100, Train metric: 2.0651
# Estimator 78/100, Train metric: 2.0352
# Estimator 79/100, Train metric: 2.0108
# Estimator 80/100, Train metric: 1.9864
# Estimator 81/100, Train metric: 1.9656
# Estimator 82/100, Train metric: 1.9415
# Estimator 83/100, Train metric: 1.9189
# Estimator 84/100, Train metric: 1.8945
# Estimator 85/100, Train metric: 1.8715
# Estimator 86/100, Train metric: 1.8515
# Estimator 87/100, Train metric: 1.8316
# Estimator 88/100, Train metric: 1.8054
# Estimator 89/100, Train metric: 1.7825
# Estimator 90/100, Train metric: 1.7635
# Estimator 91/100, Train metric: 1.7463
# Estimator 92/100, Train metric: 1.7293
# Estimator 93/100, Train metric: 1.7137
# Estimator 94/100, Train metric: 1.6933
# Estimator 95/100, Train metric: 1.6809
# Estimator 96/100, Train metric: 1.6635
# Estimator 97/100, Train metric: 1.6492
# Estimator 98/100, Train metric: 1.6331
# Estimator 99/100, Train metric: 1.6207

# %%
plot_best_scores(best_scores_autosampler,"./drive/MyDrive/NOISE/noise_ml/HyperParameter_Tuning/test_results.xlsx")

# %%
generate_interpretml_explanations_summary_pruners(best_scores_autosampler, X_train, y_train, x_test, feature_names,excel_file_path = "./drive/MyDrive/NOISE/noise_ml/HyperParameter_Tuning/test_results.xlsx")
# Out:
# WARNING:shap:Using 168 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/60 [00:00<?, ?it/s]
# WARNING:shap:Using 168 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/60 [00:00<?, ?it/s]
# WARNING:shap:Using 168 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/60 [00:00<?, ?it/s]
# WARNING:shap:Using 168 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/60 [00:00<?, ?it/s]
# WARNING:shap:Using 168 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/60 [00:00<?, ?it/s]
# WARNING:shap:Using 168 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/60 [00:00<?, ?it/s]
# WARNING:shap:Using 168 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/60 [00:00<?, ?it/s]
# Model HistGradientBoosting is not supported or not available.
# Model PGBM is not supported or not available.
